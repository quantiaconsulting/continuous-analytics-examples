# %%
pip install influxdb-client
# Out:
# Collecting influxdb-client
#   Downloading influxdb_client-1.24.0-py3-none-any.whl (524 kB)
#      |████████████████████████████████| 524 kB 740 kB/s eta 0:00:01
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (49.6.0.post20210108)
# Collecting rx>=3.0.1
#   Downloading Rx-3.2.0-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 2.1 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2020.12.5)
# Requirement already satisfied: pytz>=2019.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2021.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2.8.1)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (1.15.0)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (1.26.3)
# Installing collected packages: rx, influxdb-client
# Successfully installed influxdb-client-1.24.0 rx-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

airline = pd.read_csv("airline_passengers.csv")
train_airline = airline[:108] 
test_airline = airline[108:]

# %%
from datetime import datetime

from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS

# Local
url = "http://influxdb:8086"
token = "sda-token"
org = "sda"
bucket = "training"

client = InfluxDBClient(url=url, token=token)
write_api = client.write_api(write_options=SYNCHRONOUS)

# %%
from datetime import datetime
from datetime import timedelta

base = datetime.now().replace(second=0,microsecond=0) - timedelta(minutes=3)

# %%
base
# Out:
# datetime.datetime(2021, 11, 30, 12, 36)

# %%
from random import gauss
import time

for index, row in train_airline.iterrows():
    base += timedelta(seconds=1)
    point = Point("airline-train").field("passengers", row['Thousands of Passengers']).time(base)
    print(point.to_line_protocol())
    write_api.write(bucket, org, point)
    
for index, row in test_airline.iterrows():
    base += timedelta(seconds=1)
    point = Point("airline-test").field("passengers", row['Thousands of Passengers']).time(base)
    print(point.to_line_protocol())
    write_api.write(bucket, org, point)
# Out:
# airline-train passengers=112i 1638275761000000000
# airline-train passengers=118i 1638275762000000000
# airline-train passengers=132i 1638275763000000000
# airline-train passengers=129i 1638275764000000000
# airline-train passengers=121i 1638275765000000000
# airline-train passengers=135i 1638275766000000000
# airline-train passengers=148i 1638275767000000000
# airline-train passengers=148i 1638275768000000000
# airline-train passengers=136i 1638275769000000000
# airline-train passengers=119i 1638275770000000000
# airline-train passengers=104i 1638275771000000000
# airline-train passengers=118i 1638275772000000000
# airline-train passengers=115i 1638275773000000000
# airline-train passengers=126i 1638275774000000000
# airline-train passengers=141i 1638275775000000000
# airline-train passengers=135i 1638275776000000000
# airline-train passengers=125i 1638275777000000000
# airline-train passengers=149i 1638275778000000000
# airline-train passengers=170i 1638275779000000000
# airline-train passengers=170i 1638275780000000000
# airline-train passengers=158i 1638275781000000000
# airline-train passengers=133i 1638275782000000000
# airline-train passengers=114i 1638275783000000000
# airline-train passengers=140i 1638275784000000000
# airline-train passengers=145i 1638275785000000000
# airline-train passengers=150i 1638275786000000000
# airline-train passengers=178i 1638275787000000000
# airline-train passengers=163i 1638275788000000000
# airline-train passengers=172i 1638275789000000000
# airline-train passengers=178i 1638275790000000000
# airline-train passengers=199i 1638275791000000000
# airline-train passengers=199i 1638275792000000000
# airline-train passengers=184i 1638275793000000000
# airline-train passengers=162i 1638275794000000000
# airline-train passengers=146i 1638275795000000000
# airline-train passengers=166i 1638275796000000000
# airline-train passengers=171i 1638275797000000000
# airline-train passengers=180i 1638275798000000000
# airline-train passengers=193i 1638275799000000000
# airline-train passengers=181i 1638275800000000000
# airline-train passengers=183i 1638275801000000000
# airline-train passengers=218i 1638275802000000000
# airline-train passengers=230i 1638275803000000000
# airline-train passengers=242i 1638275804000000000
# airline-train passengers=209i 1638275805000000000
# airline-train passengers=191i 1638275806000000000
# airline-train passengers=172i 1638275807000000000
# airline-train passengers=194i 1638275808000000000
# airline-train passengers=196i 1638275809000000000
# airline-train passengers=196i 1638275810000000000
# airline-train passengers=236i 1638275811000000000
# airline-train passengers=235i 1638275812000000000
# airline-train passengers=229i 1638275813000000000
# airline-train passengers=243i 1638275814000000000
# airline-train passengers=264i 1638275815000000000
# airline-train passengers=272i 1638275816000000000
# airline-train passengers=237i 1638275817000000000
# airline-train passengers=211i 1638275818000000000
# airline-train passengers=180i 1638275819000000000
# airline-train passengers=201i 1638275820000000000
# airline-train passengers=204i 1638275821000000000
# airline-train passengers=188i 1638275822000000000
# airline-train passengers=235i 1638275823000000000
# airline-train passengers=227i 1638275824000000000
# airline-train passengers=234i 1638275825000000000
# airline-train passengers=264i 1638275826000000000
# airline-train passengers=302i 1638275827000000000
# airline-train passengers=293i 1638275828000000000
# airline-train passengers=259i 1638275829000000000
# airline-train passengers=229i 1638275830000000000
# airline-train passengers=203i 1638275831000000000
# airline-train passengers=229i 1638275832000000000
# airline-train passengers=242i 1638275833000000000
# airline-train passengers=233i 1638275834000000000
# airline-train passengers=267i 1638275835000000000
# airline-train passengers=269i 1638275836000000000
# airline-train passengers=270i 1638275837000000000
# airline-train passengers=315i 1638275838000000000
# airline-train passengers=364i 1638275839000000000
# airline-train passengers=347i 1638275840000000000
# airline-train passengers=312i 1638275841000000000
# airline-train passengers=274i 1638275842000000000
# airline-train passengers=237i 1638275843000000000
# airline-train passengers=278i 1638275844000000000
# airline-train passengers=284i 1638275845000000000
# airline-train passengers=277i 1638275846000000000
# airline-train passengers=317i 1638275847000000000
# airline-train passengers=313i 1638275848000000000
# airline-train passengers=318i 1638275849000000000
# airline-train passengers=374i 1638275850000000000
# airline-train passengers=413i 1638275851000000000
# airline-train passengers=405i 1638275852000000000
# airline-train passengers=355i 1638275853000000000
# airline-train passengers=306i 1638275854000000000
# airline-train passengers=271i 1638275855000000000
# airline-train passengers=306i 1638275856000000000
# airline-train passengers=315i 1638275857000000000
# airline-train passengers=301i 1638275858000000000
# airline-train passengers=356i 1638275859000000000
# airline-train passengers=348i 1638275860000000000
# airline-train passengers=355i 1638275861000000000
# airline-train passengers=422i 1638275862000000000
# airline-train passengers=465i 1638275863000000000
# airline-train passengers=467i 1638275864000000000
# airline-train passengers=404i 1638275865000000000
# airline-train passengers=347i 1638275866000000000
# airline-train passengers=305i 1638275867000000000
# airline-train passengers=336i 1638275868000000000
# airline-test passengers=340i 1638275869000000000
# airline-test passengers=318i 1638275870000000000
# airline-test passengers=362i 1638275871000000000
# airline-test passengers=348i 1638275872000000000
# airline-test passengers=363i 1638275873000000000
# airline-test passengers=435i 1638275874000000000
# airline-test passengers=491i 1638275875000000000
# airline-test passengers=505i 1638275876000000000
# airline-test passengers=404i 1638275877000000000
# airline-test passengers=359i 1638275878000000000
# airline-test passengers=310i 1638275879000000000
# airline-test passengers=337i 1638275880000000000
# airline-test passengers=360i 1638275881000000000
# airline-test passengers=342i 1638275882000000000
# airline-test passengers=406i 1638275883000000000
# airline-test passengers=396i 1638275884000000000
# airline-test passengers=420i 1638275885000000000
# airline-test passengers=472i 1638275886000000000
# airline-test passengers=548i 1638275887000000000
# airline-test passengers=559i 1638275888000000000
# airline-test passengers=463i 1638275889000000000
# airline-test passengers=407i 1638275890000000000
# airline-test passengers=362i 1638275891000000000
# airline-test passengers=405i 1638275892000000000
# airline-test passengers=417i 1638275893000000000
# airline-test passengers=391i 1638275894000000000
# airline-test passengers=419i 1638275895000000000
# airline-test passengers=461i 1638275896000000000
# airline-test passengers=472i 1638275897000000000
# airline-test passengers=535i 1638275898000000000
# airline-test passengers=622i 1638275899000000000
# airline-test passengers=606i 1638275900000000000
# airline-test passengers=508i 1638275901000000000
# airline-test passengers=461i 1638275902000000000
# airline-test passengers=390i 1638275903000000000
# airline-test passengers=432i 1638275904000000000
