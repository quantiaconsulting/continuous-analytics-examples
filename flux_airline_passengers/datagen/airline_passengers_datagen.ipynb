# %%
pip install influxdb-client
# Out:
# Collecting influxdb-client
#   Downloading influxdb_client-1.24.0-py3-none-any.whl (524 kB)
#      |████████████████████████████████| 524 kB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2.8.1)
# Collecting rx>=3.0.1
#   Downloading Rx-3.2.0-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 2.6 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (1.15.0)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (1.26.3)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (49.6.0.post20210108)
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2020.12.5)
# Requirement already satisfied: pytz>=2019.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2021.1)
# Installing collected packages: rx, influxdb-client
# Successfully installed influxdb-client-1.24.0 rx-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

airline = pd.read_csv("airline_passengers.csv")
train_airline = airline[:108] 
test_airline = airline[108:]

# %%
from datetime import datetime

from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS

# Local
url = "http://influxdb:8086"
token = "sda-token"
org = "sda"
bucket = "training"

client = InfluxDBClient(url=url, token=token)
write_api = client.write_api(write_options=SYNCHRONOUS)

# %%
from datetime import datetime
from datetime import timedelta

base = datetime.now().replace(second=0,microsecond=0) - timedelta(minutes=3)

# %%
base
# Out:
# datetime.datetime(2021, 12, 7, 7, 37)

# %%
from random import gauss
import time

for index, row in train_airline.iterrows():
    base += timedelta(seconds=1)
    point = Point("airline-train").field("passengers", row['Thousands of Passengers']).time(base)
    print(point.to_line_protocol())
    write_api.write(bucket, org, point)
    
for index, row in test_airline.iterrows():
    base += timedelta(seconds=1)
    point = Point("airline-test").field("passengers", row['Thousands of Passengers']).time(base)
    print(point.to_line_protocol())
    write_api.write(bucket, org, point)
# Out:
# airline-train passengers=112i 1638862621000000000
# airline-train passengers=118i 1638862622000000000
# airline-train passengers=132i 1638862623000000000
# airline-train passengers=129i 1638862624000000000
# airline-train passengers=121i 1638862625000000000
# airline-train passengers=135i 1638862626000000000
# airline-train passengers=148i 1638862627000000000
# airline-train passengers=148i 1638862628000000000
# airline-train passengers=136i 1638862629000000000
# airline-train passengers=119i 1638862630000000000
# airline-train passengers=104i 1638862631000000000
# airline-train passengers=118i 1638862632000000000
# airline-train passengers=115i 1638862633000000000
# airline-train passengers=126i 1638862634000000000
# airline-train passengers=141i 1638862635000000000
# airline-train passengers=135i 1638862636000000000
# airline-train passengers=125i 1638862637000000000
# airline-train passengers=149i 1638862638000000000
# airline-train passengers=170i 1638862639000000000
# airline-train passengers=170i 1638862640000000000
# airline-train passengers=158i 1638862641000000000
# airline-train passengers=133i 1638862642000000000
# airline-train passengers=114i 1638862643000000000
# airline-train passengers=140i 1638862644000000000
# airline-train passengers=145i 1638862645000000000
# airline-train passengers=150i 1638862646000000000
# airline-train passengers=178i 1638862647000000000
# airline-train passengers=163i 1638862648000000000
# airline-train passengers=172i 1638862649000000000
# airline-train passengers=178i 1638862650000000000
# airline-train passengers=199i 1638862651000000000
# airline-train passengers=199i 1638862652000000000
# airline-train passengers=184i 1638862653000000000
# airline-train passengers=162i 1638862654000000000
# airline-train passengers=146i 1638862655000000000
# airline-train passengers=166i 1638862656000000000
# airline-train passengers=171i 1638862657000000000
# airline-train passengers=180i 1638862658000000000
# airline-train passengers=193i 1638862659000000000
# airline-train passengers=181i 1638862660000000000
# airline-train passengers=183i 1638862661000000000
# airline-train passengers=218i 1638862662000000000
# airline-train passengers=230i 1638862663000000000
# airline-train passengers=242i 1638862664000000000
# airline-train passengers=209i 1638862665000000000
# airline-train passengers=191i 1638862666000000000
# airline-train passengers=172i 1638862667000000000
# airline-train passengers=194i 1638862668000000000
# airline-train passengers=196i 1638862669000000000
# airline-train passengers=196i 1638862670000000000
# airline-train passengers=236i 1638862671000000000
# airline-train passengers=235i 1638862672000000000
# airline-train passengers=229i 1638862673000000000
# airline-train passengers=243i 1638862674000000000
# airline-train passengers=264i 1638862675000000000
# airline-train passengers=272i 1638862676000000000
# airline-train passengers=237i 1638862677000000000
# airline-train passengers=211i 1638862678000000000
# airline-train passengers=180i 1638862679000000000
# airline-train passengers=201i 1638862680000000000
# airline-train passengers=204i 1638862681000000000
# airline-train passengers=188i 1638862682000000000
# airline-train passengers=235i 1638862683000000000
# airline-train passengers=227i 1638862684000000000
# airline-train passengers=234i 1638862685000000000
# airline-train passengers=264i 1638862686000000000
# airline-train passengers=302i 1638862687000000000
# airline-train passengers=293i 1638862688000000000
# airline-train passengers=259i 1638862689000000000
# airline-train passengers=229i 1638862690000000000
# airline-train passengers=203i 1638862691000000000
# airline-train passengers=229i 1638862692000000000
# airline-train passengers=242i 1638862693000000000
# airline-train passengers=233i 1638862694000000000
# airline-train passengers=267i 1638862695000000000
# airline-train passengers=269i 1638862696000000000
# airline-train passengers=270i 1638862697000000000
# airline-train passengers=315i 1638862698000000000
# airline-train passengers=364i 1638862699000000000
# airline-train passengers=347i 1638862700000000000
# airline-train passengers=312i 1638862701000000000
# airline-train passengers=274i 1638862702000000000
# airline-train passengers=237i 1638862703000000000
# airline-train passengers=278i 1638862704000000000
# airline-train passengers=284i 1638862705000000000
# airline-train passengers=277i 1638862706000000000
# airline-train passengers=317i 1638862707000000000
# airline-train passengers=313i 1638862708000000000
# airline-train passengers=318i 1638862709000000000
# airline-train passengers=374i 1638862710000000000
# airline-train passengers=413i 1638862711000000000
# airline-train passengers=405i 1638862712000000000
# airline-train passengers=355i 1638862713000000000
# airline-train passengers=306i 1638862714000000000
# airline-train passengers=271i 1638862715000000000
# airline-train passengers=306i 1638862716000000000
# airline-train passengers=315i 1638862717000000000
# airline-train passengers=301i 1638862718000000000
# airline-train passengers=356i 1638862719000000000
# airline-train passengers=348i 1638862720000000000
# airline-train passengers=355i 1638862721000000000
# airline-train passengers=422i 1638862722000000000
# airline-train passengers=465i 1638862723000000000
# airline-train passengers=467i 1638862724000000000
# airline-train passengers=404i 1638862725000000000
# airline-train passengers=347i 1638862726000000000
# airline-train passengers=305i 1638862727000000000
# airline-train passengers=336i 1638862728000000000
# airline-test passengers=340i 1638862729000000000
# airline-test passengers=318i 1638862730000000000
# airline-test passengers=362i 1638862731000000000
# airline-test passengers=348i 1638862732000000000
# airline-test passengers=363i 1638862733000000000
# airline-test passengers=435i 1638862734000000000
# airline-test passengers=491i 1638862735000000000
# airline-test passengers=505i 1638862736000000000
# airline-test passengers=404i 1638862737000000000
# airline-test passengers=359i 1638862738000000000
# airline-test passengers=310i 1638862739000000000
# airline-test passengers=337i 1638862740000000000
# airline-test passengers=360i 1638862741000000000
# airline-test passengers=342i 1638862742000000000
# airline-test passengers=406i 1638862743000000000
# airline-test passengers=396i 1638862744000000000
# airline-test passengers=420i 1638862745000000000
# airline-test passengers=472i 1638862746000000000
# airline-test passengers=548i 1638862747000000000
# airline-test passengers=559i 1638862748000000000
# airline-test passengers=463i 1638862749000000000
# airline-test passengers=407i 1638862750000000000
# airline-test passengers=362i 1638862751000000000
# airline-test passengers=405i 1638862752000000000
# airline-test passengers=417i 1638862753000000000
# airline-test passengers=391i 1638862754000000000
# airline-test passengers=419i 1638862755000000000
# airline-test passengers=461i 1638862756000000000
# airline-test passengers=472i 1638862757000000000
# airline-test passengers=535i 1638862758000000000
# airline-test passengers=622i 1638862759000000000
# airline-test passengers=606i 1638862760000000000
# airline-test passengers=508i 1638862761000000000
# airline-test passengers=461i 1638862762000000000
# airline-test passengers=390i 1638862763000000000
# airline-test passengers=432i 1638862764000000000
