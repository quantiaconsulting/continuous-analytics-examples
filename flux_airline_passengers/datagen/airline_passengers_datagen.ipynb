# %%
pip install influxdb-client
# Out:
# Collecting influxdb-client
#   Downloading influxdb_client-1.24.0-py3-none-any.whl (524 kB)
#      |████████████████████████████████| 524 kB 841 kB/s eta 0:00:01
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (1.15.0)
# Collecting rx>=3.0.1
#   Downloading Rx-3.2.0-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2019.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2021.1)
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2020.12.5)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2.8.1)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (49.6.0.post20210108)
# Installing collected packages: rx, influxdb-client
# Successfully installed influxdb-client-1.24.0 rx-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

airline = pd.read_csv("airline_passengers.csv")
train_airline = airline[:108] 
test_airline = airline[108:]

# %%
from datetime import datetime

from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS

# Local
url = "http://influxdb:8086"
token = "sda-token"
org = "sda"
bucket = "training"

client = InfluxDBClient(url=url, token=token)
write_api = client.write_api(write_options=SYNCHRONOUS)

# %%
from datetime import datetime
from datetime import timedelta

base = datetime.now().replace(second=0,microsecond=0) - timedelta(minutes=3)

# %%
base
# Out:
# datetime.datetime(2021, 12, 2, 13, 8)

# %%
from random import gauss
import time

for index, row in train_airline.iterrows():
    base += timedelta(seconds=1)
    point = Point("airline-train").field("passengers", row['Thousands of Passengers']).time(base)
    print(point.to_line_protocol())
    write_api.write(bucket, org, point)
    
for index, row in test_airline.iterrows():
    base += timedelta(seconds=1)
    point = Point("airline-test").field("passengers", row['Thousands of Passengers']).time(base)
    print(point.to_line_protocol())
    write_api.write(bucket, org, point)
# Out:
# airline-train passengers=112i 1638450481000000000
# airline-train passengers=118i 1638450482000000000
# airline-train passengers=132i 1638450483000000000
# airline-train passengers=129i 1638450484000000000
# airline-train passengers=121i 1638450485000000000
# airline-train passengers=135i 1638450486000000000
# airline-train passengers=148i 1638450487000000000
# airline-train passengers=148i 1638450488000000000
# airline-train passengers=136i 1638450489000000000
# airline-train passengers=119i 1638450490000000000
# airline-train passengers=104i 1638450491000000000
# airline-train passengers=118i 1638450492000000000
# airline-train passengers=115i 1638450493000000000
# airline-train passengers=126i 1638450494000000000
# airline-train passengers=141i 1638450495000000000
# airline-train passengers=135i 1638450496000000000
# airline-train passengers=125i 1638450497000000000
# airline-train passengers=149i 1638450498000000000
# airline-train passengers=170i 1638450499000000000
# airline-train passengers=170i 1638450500000000000
# airline-train passengers=158i 1638450501000000000
# airline-train passengers=133i 1638450502000000000
# airline-train passengers=114i 1638450503000000000
# airline-train passengers=140i 1638450504000000000
# airline-train passengers=145i 1638450505000000000
# airline-train passengers=150i 1638450506000000000
# airline-train passengers=178i 1638450507000000000
# airline-train passengers=163i 1638450508000000000
# airline-train passengers=172i 1638450509000000000
# airline-train passengers=178i 1638450510000000000
# airline-train passengers=199i 1638450511000000000
# airline-train passengers=199i 1638450512000000000
# airline-train passengers=184i 1638450513000000000
# airline-train passengers=162i 1638450514000000000
# airline-train passengers=146i 1638450515000000000
# airline-train passengers=166i 1638450516000000000
# airline-train passengers=171i 1638450517000000000
# airline-train passengers=180i 1638450518000000000
# airline-train passengers=193i 1638450519000000000
# airline-train passengers=181i 1638450520000000000
# airline-train passengers=183i 1638450521000000000
# airline-train passengers=218i 1638450522000000000
# airline-train passengers=230i 1638450523000000000
# airline-train passengers=242i 1638450524000000000
# airline-train passengers=209i 1638450525000000000
# airline-train passengers=191i 1638450526000000000
# airline-train passengers=172i 1638450527000000000
# airline-train passengers=194i 1638450528000000000
# airline-train passengers=196i 1638450529000000000
# airline-train passengers=196i 1638450530000000000
# airline-train passengers=236i 1638450531000000000
# airline-train passengers=235i 1638450532000000000
# airline-train passengers=229i 1638450533000000000
# airline-train passengers=243i 1638450534000000000
# airline-train passengers=264i 1638450535000000000
# airline-train passengers=272i 1638450536000000000
# airline-train passengers=237i 1638450537000000000
# airline-train passengers=211i 1638450538000000000
# airline-train passengers=180i 1638450539000000000
# airline-train passengers=201i 1638450540000000000
# airline-train passengers=204i 1638450541000000000
# airline-train passengers=188i 1638450542000000000
# airline-train passengers=235i 1638450543000000000
# airline-train passengers=227i 1638450544000000000
# airline-train passengers=234i 1638450545000000000
# airline-train passengers=264i 1638450546000000000
# airline-train passengers=302i 1638450547000000000
# airline-train passengers=293i 1638450548000000000
# airline-train passengers=259i 1638450549000000000
# airline-train passengers=229i 1638450550000000000
# airline-train passengers=203i 1638450551000000000
# airline-train passengers=229i 1638450552000000000
# airline-train passengers=242i 1638450553000000000
# airline-train passengers=233i 1638450554000000000
# airline-train passengers=267i 1638450555000000000
# airline-train passengers=269i 1638450556000000000
# airline-train passengers=270i 1638450557000000000
# airline-train passengers=315i 1638450558000000000
# airline-train passengers=364i 1638450559000000000
# airline-train passengers=347i 1638450560000000000
# airline-train passengers=312i 1638450561000000000
# airline-train passengers=274i 1638450562000000000
# airline-train passengers=237i 1638450563000000000
# airline-train passengers=278i 1638450564000000000
# airline-train passengers=284i 1638450565000000000
# airline-train passengers=277i 1638450566000000000
# airline-train passengers=317i 1638450567000000000
# airline-train passengers=313i 1638450568000000000
# airline-train passengers=318i 1638450569000000000
# airline-train passengers=374i 1638450570000000000
# airline-train passengers=413i 1638450571000000000
# airline-train passengers=405i 1638450572000000000
# airline-train passengers=355i 1638450573000000000
# airline-train passengers=306i 1638450574000000000
# airline-train passengers=271i 1638450575000000000
# airline-train passengers=306i 1638450576000000000
# airline-train passengers=315i 1638450577000000000
# airline-train passengers=301i 1638450578000000000
# airline-train passengers=356i 1638450579000000000
# airline-train passengers=348i 1638450580000000000
# airline-train passengers=355i 1638450581000000000
# airline-train passengers=422i 1638450582000000000
# airline-train passengers=465i 1638450583000000000
# airline-train passengers=467i 1638450584000000000
# airline-train passengers=404i 1638450585000000000
# airline-train passengers=347i 1638450586000000000
# airline-train passengers=305i 1638450587000000000
# airline-train passengers=336i 1638450588000000000
# airline-test passengers=340i 1638450589000000000
# airline-test passengers=318i 1638450590000000000
# airline-test passengers=362i 1638450591000000000
# airline-test passengers=348i 1638450592000000000
# airline-test passengers=363i 1638450593000000000
# airline-test passengers=435i 1638450594000000000
# airline-test passengers=491i 1638450595000000000
# airline-test passengers=505i 1638450596000000000
# airline-test passengers=404i 1638450597000000000
# airline-test passengers=359i 1638450598000000000
# airline-test passengers=310i 1638450599000000000
# airline-test passengers=337i 1638450600000000000
# airline-test passengers=360i 1638450601000000000
# airline-test passengers=342i 1638450602000000000
# airline-test passengers=406i 1638450603000000000
# airline-test passengers=396i 1638450604000000000
# airline-test passengers=420i 1638450605000000000
# airline-test passengers=472i 1638450606000000000
# airline-test passengers=548i 1638450607000000000
# airline-test passengers=559i 1638450608000000000
# airline-test passengers=463i 1638450609000000000
# airline-test passengers=407i 1638450610000000000
# airline-test passengers=362i 1638450611000000000
# airline-test passengers=405i 1638450612000000000
# airline-test passengers=417i 1638450613000000000
# airline-test passengers=391i 1638450614000000000
# airline-test passengers=419i 1638450615000000000
# airline-test passengers=461i 1638450616000000000
# airline-test passengers=472i 1638450617000000000
# airline-test passengers=535i 1638450618000000000
# airline-test passengers=622i 1638450619000000000
# airline-test passengers=606i 1638450620000000000
# airline-test passengers=508i 1638450621000000000
# airline-test passengers=461i 1638450622000000000
# airline-test passengers=390i 1638450623000000000
# airline-test passengers=432i 1638450624000000000
