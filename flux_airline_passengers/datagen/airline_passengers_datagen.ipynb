# %%
pip install influxdb-client
# Out:
# Requirement already satisfied: influxdb-client in /opt/conda/lib/python3.8/site-packages (1.24.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2.8.1)
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2020.12.5)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (49.6.0.post20210108)
# Requirement already satisfied: rx>=3.0.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (3.2.0)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (1.26.3)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (1.15.0)
# Requirement already satisfied: pytz>=2019.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2021.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

airline = pd.read_csv("airline_passengers.csv")
train_airline = airline[:108] 
test_airline = airline[108:]

# %%
from datetime import datetime

from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS

# Local
url = "http://influxdb:8086"
token = "sda-token"
org = "sda"
bucket = "training"

client = InfluxDBClient(url=url, token=token)
write_api = client.write_api(write_options=SYNCHRONOUS)

# %%
from datetime import datetime
from datetime import timedelta

base = datetime.now().replace(second=0,microsecond=0) - timedelta(minutes=3)

# %%
base
# Out:
# datetime.datetime(2021, 12, 2, 10, 25)

# %%
from random import gauss
import time

for index, row in train_airline.iterrows():
    base += timedelta(seconds=1)
    point = Point("airline-train").field("passengers", row['Thousands of Passengers']).time(base)
    print(point.to_line_protocol())
    write_api.write(bucket, org, point)
    
for index, row in test_airline.iterrows():
    base += timedelta(seconds=1)
    point = Point("airline-test").field("passengers", row['Thousands of Passengers']).time(base)
    print(point.to_line_protocol())
    write_api.write(bucket, org, point)
# Out:
# airline-train passengers=112i 1638440701000000000
# airline-train passengers=118i 1638440702000000000
# airline-train passengers=132i 1638440703000000000
# airline-train passengers=129i 1638440704000000000
# airline-train passengers=121i 1638440705000000000
# airline-train passengers=135i 1638440706000000000
# airline-train passengers=148i 1638440707000000000
# airline-train passengers=148i 1638440708000000000
# airline-train passengers=136i 1638440709000000000
# airline-train passengers=119i 1638440710000000000
# airline-train passengers=104i 1638440711000000000
# airline-train passengers=118i 1638440712000000000
# airline-train passengers=115i 1638440713000000000
# airline-train passengers=126i 1638440714000000000
# airline-train passengers=141i 1638440715000000000
# airline-train passengers=135i 1638440716000000000
# airline-train passengers=125i 1638440717000000000
# airline-train passengers=149i 1638440718000000000
# airline-train passengers=170i 1638440719000000000
# airline-train passengers=170i 1638440720000000000
# airline-train passengers=158i 1638440721000000000
# airline-train passengers=133i 1638440722000000000
# airline-train passengers=114i 1638440723000000000
# airline-train passengers=140i 1638440724000000000
# airline-train passengers=145i 1638440725000000000
# airline-train passengers=150i 1638440726000000000
# airline-train passengers=178i 1638440727000000000
# airline-train passengers=163i 1638440728000000000
# airline-train passengers=172i 1638440729000000000
# airline-train passengers=178i 1638440730000000000
# airline-train passengers=199i 1638440731000000000
# airline-train passengers=199i 1638440732000000000
# airline-train passengers=184i 1638440733000000000
# airline-train passengers=162i 1638440734000000000
# airline-train passengers=146i 1638440735000000000
# airline-train passengers=166i 1638440736000000000
# airline-train passengers=171i 1638440737000000000
# airline-train passengers=180i 1638440738000000000
# airline-train passengers=193i 1638440739000000000
# airline-train passengers=181i 1638440740000000000
# airline-train passengers=183i 1638440741000000000
# airline-train passengers=218i 1638440742000000000
# airline-train passengers=230i 1638440743000000000
# airline-train passengers=242i 1638440744000000000
# airline-train passengers=209i 1638440745000000000
# airline-train passengers=191i 1638440746000000000
# airline-train passengers=172i 1638440747000000000
# airline-train passengers=194i 1638440748000000000
# airline-train passengers=196i 1638440749000000000
# airline-train passengers=196i 1638440750000000000
# airline-train passengers=236i 1638440751000000000
# airline-train passengers=235i 1638440752000000000
# airline-train passengers=229i 1638440753000000000
# airline-train passengers=243i 1638440754000000000
# airline-train passengers=264i 1638440755000000000
# airline-train passengers=272i 1638440756000000000
# airline-train passengers=237i 1638440757000000000
# airline-train passengers=211i 1638440758000000000
# airline-train passengers=180i 1638440759000000000
# airline-train passengers=201i 1638440760000000000
# airline-train passengers=204i 1638440761000000000
# airline-train passengers=188i 1638440762000000000
# airline-train passengers=235i 1638440763000000000
# airline-train passengers=227i 1638440764000000000
# airline-train passengers=234i 1638440765000000000
# airline-train passengers=264i 1638440766000000000
# airline-train passengers=302i 1638440767000000000
# airline-train passengers=293i 1638440768000000000
# airline-train passengers=259i 1638440769000000000
# airline-train passengers=229i 1638440770000000000
# airline-train passengers=203i 1638440771000000000
# airline-train passengers=229i 1638440772000000000
# airline-train passengers=242i 1638440773000000000
# airline-train passengers=233i 1638440774000000000
# airline-train passengers=267i 1638440775000000000
# airline-train passengers=269i 1638440776000000000
# airline-train passengers=270i 1638440777000000000
# airline-train passengers=315i 1638440778000000000
# airline-train passengers=364i 1638440779000000000
# airline-train passengers=347i 1638440780000000000
# airline-train passengers=312i 1638440781000000000
# airline-train passengers=274i 1638440782000000000
# airline-train passengers=237i 1638440783000000000
# airline-train passengers=278i 1638440784000000000
# airline-train passengers=284i 1638440785000000000
# airline-train passengers=277i 1638440786000000000
# airline-train passengers=317i 1638440787000000000
# airline-train passengers=313i 1638440788000000000
# airline-train passengers=318i 1638440789000000000
# airline-train passengers=374i 1638440790000000000
# airline-train passengers=413i 1638440791000000000
# airline-train passengers=405i 1638440792000000000
# airline-train passengers=355i 1638440793000000000
# airline-train passengers=306i 1638440794000000000
# airline-train passengers=271i 1638440795000000000
# airline-train passengers=306i 1638440796000000000
# airline-train passengers=315i 1638440797000000000
# airline-train passengers=301i 1638440798000000000
# airline-train passengers=356i 1638440799000000000
# airline-train passengers=348i 1638440800000000000
# airline-train passengers=355i 1638440801000000000
# airline-train passengers=422i 1638440802000000000
# airline-train passengers=465i 1638440803000000000
# airline-train passengers=467i 1638440804000000000
# airline-train passengers=404i 1638440805000000000
# airline-train passengers=347i 1638440806000000000
# airline-train passengers=305i 1638440807000000000
# airline-train passengers=336i 1638440808000000000
# airline-test passengers=340i 1638440809000000000
# airline-test passengers=318i 1638440810000000000
# airline-test passengers=362i 1638440811000000000
# airline-test passengers=348i 1638440812000000000
# airline-test passengers=363i 1638440813000000000
# airline-test passengers=435i 1638440814000000000
# airline-test passengers=491i 1638440815000000000
# airline-test passengers=505i 1638440816000000000
# airline-test passengers=404i 1638440817000000000
# airline-test passengers=359i 1638440818000000000
# airline-test passengers=310i 1638440819000000000
# airline-test passengers=337i 1638440820000000000
# airline-test passengers=360i 1638440821000000000
# airline-test passengers=342i 1638440822000000000
# airline-test passengers=406i 1638440823000000000
# airline-test passengers=396i 1638440824000000000
# airline-test passengers=420i 1638440825000000000
# airline-test passengers=472i 1638440826000000000
# airline-test passengers=548i 1638440827000000000
# airline-test passengers=559i 1638440828000000000
# airline-test passengers=463i 1638440829000000000
# airline-test passengers=407i 1638440830000000000
# airline-test passengers=362i 1638440831000000000
# airline-test passengers=405i 1638440832000000000
# airline-test passengers=417i 1638440833000000000
# airline-test passengers=391i 1638440834000000000
# airline-test passengers=419i 1638440835000000000
# airline-test passengers=461i 1638440836000000000
# airline-test passengers=472i 1638440837000000000
# airline-test passengers=535i 1638440838000000000
# airline-test passengers=622i 1638440839000000000
# airline-test passengers=606i 1638440840000000000
# airline-test passengers=508i 1638440841000000000
# airline-test passengers=461i 1638440842000000000
# airline-test passengers=390i 1638440843000000000
# airline-test passengers=432i 1638440844000000000
