# %% [markdown]
# # Spark Structured Streaming - Demo
# ## Robotic Arm

# %%
import os
from pyspark.sql import SparkSession
from pyspark.streaming import StreamingContext
import io
from pyspark.sql.functions import *
import time
import json
import struct
import requests 

os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.1,org.apache.spark:spark-streaming-kafka-0-10_2.11:2.4.5,org.apache.kafka:kafka-clients:2.6.0 pyspark-shell'
                                    
spark = (SparkSession.builder 
    .master("local[*]")
    .appName("test")
    .getOrCreate()
        )

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7617fb559195:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# set up the environment variables

# %%
topic = 'RoboticArm'
servers = "kafka:9092"

# %% [markdown]
# ### Let's create the streaming Data Frames using the data in the kafka topics

# %%
raw_RoboticArm_df = (spark
  .readStream
  .format("kafka")
  .option("kafka.bootstrap.servers", servers)
  .option("startingOffsets", "earliest")
  .option("subscribe", topic)
  .load())

# %%
raw_RoboticArm_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
from pyspark.sql.types import *

RoboticArm_schema = StructType([
    StructField("id", StringType(), True),
    StructField("status", StringType(), True),
    StructField("stressLevel", IntegerType(), True),
    StructField("ts", TimestampType(), True)])

# %%
RoboticArm_sdf=(raw_RoboticArm_df
                      .select(from_json(col("value").cast("string"), RoboticArm_schema).alias("value"))
                      .select("value.*"))

# %%
RoboticArm_sdf.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- stressLevel: integer (nullable = true)
#  |-- ts: timestamp (nullable = true)

# %% [markdown]
# ### to gain some confidence, let's first inspect the content of the stream of smoke event

# %%
basic_query = (RoboticArm_sdf
    .writeStream
    .format("memory") # this is for debug purpose only! DO NOT USE IN PRODUCTION
    .queryName("sinkTable")
    .start())

# %%
spark.sql("SELECT * FROM sinkTable ORDER BY TS DESC").show(5)
# Out:
# +---+-----------+-----------+-------------------+
# | id|     status|stressLevel|                 ts|
# +---+-----------+-----------+-------------------+
# |  1|placingGood|          3|2021-10-18 14:50:30|
# |  2|placingGood|          3|2021-10-18 14:50:30|
# |  2| movingGood|          9|2021-10-18 14:50:20|
# |  2|goodGrasped|          5|2021-10-18 14:50:19|
# |  2|      ready|          0|2021-10-18 14:50:17|
# +---+-----------+-----------+-------------------+
# only showing top 5 rows

# %% [markdown]
# do not forget to stop queries that you are not using

# %%
basic_query.stop()

# %% [markdown]
# ## E2
#
# Write a continuous query that emits the max stress for each arm.

# %% [markdown]
# ### the SQL sytyle

# %%
# create a logic table on top of the streaming data frame
RoboticArm_sdf.createTempView("RoboticArm") # this time we will not clean it up, because we use it in the next queries

# %% [markdown]
# **NOTE**: the following query gives *intentionally* an error

# %%
query_string = """
SELECT id, MAX(stressLevel) 
FROM RoboticArm
GROUP BY id
"""

# write your query in SQL, register it and start it
e2 = (spark.sql(query_string)
                     .writeStream
                     .format("memory")
                     .outputMode("complete") 
                     .queryName("sinkTable")
                     .start())

# %%
# look up the most recent results
spark.sql("SELECT * FROM sinkTable").show(5) # without ORDER BY TS DESC because the result in the table is already only the most recent

# %%
# clean up
e2.stop()

# %% [markdown]
# ### The DataFrame style

# %%
e2bis = (RoboticArm_sdf
                     .groupBy("id")
                     .max()
                     .writeStream
                     .format("memory")
                     .outputMode("complete") # 
                     .queryName("sinkTable")
                     .start())

# %%
# look up the most recent results
spark.sql("SELECT * FROM sinkTable").show(5) # woithout ORDER BY TS DESC because the result in the table is already only the most recent

# %%
# clean up
e2bis.stop()

# %% [markdown]
# # E3
# A continuous query that emits the average stress level between a pick (status==goodGrasped) and a place (status==placingGood).
# iniziamo con una cosa più semplice
# ## E3.1
# per ora cercate di trovare un braccio in status moving seguito dallo stesso braccio in status placing e restituire lo stress level in status moving e lo stress level in status placing (edited)

# %%
moving_sdf = (RoboticArm_sdf
              .withWatermark("ts","30 seconds")
              .where("status='movingGood'")
              .withColumnRenamed("id","idMoving")
              .withColumnRenamed("status","statusMoving")
              .withColumnRenamed("stressLevel","stressLevelMoving")
              .withColumnRenamed("ts","tsMoving")
             )
placing_sdf = (RoboticArm_sdf
              .withWatermark("ts","30 seconds")
               .where("status='placingGood'")
              .withColumnRenamed("id","idPlacing")
              .withColumnRenamed("status","statusPlacing")
              .withColumnRenamed("stressLevel","stressLevelPlacing")
              .withColumnRenamed("ts","tsPlacing")
              )

# %%
joins_sdf = moving_sdf.join(placing_sdf,
                            expr("""
                            idPlacing=idMoving AND
                            tsPlacing > tsMoving AND
                            tsPlacing <= tsMoving + interval 14 seconds
                            """))

# %%
e31 = (joins_sdf
                     .writeStream
                     .format("memory")
                     #.outputMode("complete") # 
                     .queryName("sinkTable")
                     .start())

# %%
# look up the most recent results
spark.sql("SELECT * FROM sinkTable").show(5)
# Out:
# +--------+------------+-----------------+-------------------+---------+-------------+------------------+-------------------+
# |idMoving|statusMoving|stressLevelMoving|           tsMoving|idPlacing|statusPlacing|stressLevelPlacing|          tsPlacing|
# +--------+------------+-----------------+-------------------+---------+-------------+------------------+-------------------+
# |       1|  movingGood|                7|2021-10-18 14:22:07|        1|  placingGood|                 3|2021-10-18 14:22:20|
# |       1|  movingGood|                7|2021-10-18 14:22:40|        1|  placingGood|                 3|2021-10-18 14:22:53|
# |       1|  movingGood|                7|2021-10-18 14:23:13|        1|  placingGood|                 3|2021-10-18 14:23:26|
# |       1|  movingGood|                7|2021-10-18 14:23:46|        1|  placingGood|                 3|2021-10-18 14:23:59|
# |       1|  movingGood|                7|2021-10-18 14:24:19|        1|  placingGood|                 3|2021-10-18 14:24:32|
# +--------+------------+-----------------+-------------------+---------+-------------+------------------+-------------------+
# only showing top 5 rows

# %%
spark.sql("SELECT idPlacing, tsPlacing, count(*) FROM sinkTable GROUP BY idPlacing, tsPlacing ORDER BY tsPlacing DESC").show(5)
# Out:
# +---------+-------------------+--------+
# |idPlacing|          tsPlacing|count(1)|
# +---------+-------------------+--------+
# |        2|2021-10-18 15:15:21|       1|
# |        1|2021-10-18 15:15:21|       1|
# |        1|2021-10-18 15:14:48|       1|
# |        2|2021-10-18 15:14:48|       1|
# |        2|2021-10-18 15:14:15|       1|
# +---------+-------------------+--------+
# only showing top 5 rows

# %%
e31.stop()

# %%
e31.recentProgress
# Out:
# [{'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:36:45.329Z',
#   'batchId': 201,
#   'numInputRows': 10,
#   'inputRowsPerSecond': 1.3598041881968996,
#   'processedRowsPerSecond': 1.530690341343946,
#   'durationMs': {'addBatch': 6354,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 125,
#    'triggerExecution': 6533,
#    'walCommit': 32},
#   'eventTime': {'avg': '2021-10-18T15:36:41.500Z',
#    'max': '2021-10-18T15:36:43.000Z',
#    'min': '2021-10-18T15:36:40.000Z',
#    'watermark': '2021-10-18T15:35:40.000Z'},
#   'stateOperators': [{'numRowsTotal': 10,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330336,
#     'customMetrics': {'loadedMapCacheHitCount': 80400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37776}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1621}},
#     'endOffset': {'RoboticArm': {'0': 1626}},
#     'numInputRows': 10,
#     'inputRowsPerSecond': 1.3598041881968996,
#     'processedRowsPerSecond': 1.530690341343946}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:36:51.863Z',
#   'batchId': 202,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 6186,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 125,
#    'triggerExecution': 6368,
#    'walCommit': 32},
#   'eventTime': {'watermark': '2021-10-18T15:35:50.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330824,
#     'customMetrics': {'loadedMapCacheHitCount': 80800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37096}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1626}},
#     'endOffset': {'RoboticArm': {'0': 1626}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:36:58.232Z',
#   'batchId': 203,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.6280420788192809,
#   'processedRowsPerSecond': 0.6299212598425197,
#   'durationMs': {'addBatch': 6176,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 126,
#    'triggerExecution': 6350,
#    'walCommit': 25},
#   'eventTime': {'avg': '2021-10-18T15:36:53.000Z',
#    'max': '2021-10-18T15:36:53.000Z',
#    'min': '2021-10-18T15:36:53.000Z',
#    'watermark': '2021-10-18T15:35:50.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330376,
#     'customMetrics': {'loadedMapCacheHitCount': 81200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1626}},
#     'endOffset': {'RoboticArm': {'0': 1628}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.6280420788192809,
#     'processedRowsPerSecond': 0.6299212598425197}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:37:04.583Z',
#   'batchId': 204,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.629822075263738,
#   'processedRowsPerSecond': 0.6572461386789352,
#   'durationMs': {'addBatch': 5925,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 120,
#    'triggerExecution': 6086,
#    'walCommit': 26},
#   'eventTime': {'watermark': '2021-10-18T15:36:13.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330176,
#     'customMetrics': {'loadedMapCacheHitCount': 81600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37312}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1628}},
#     'endOffset': {'RoboticArm': {'0': 1630}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.629822075263738,
#     'processedRowsPerSecond': 0.6572461386789352}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:37:10.669Z',
#   'batchId': 205,
#   'numInputRows': 6,
#   'inputRowsPerSecond': 0.9858692080184028,
#   'processedRowsPerSecond': 1.029512697323267,
#   'durationMs': {'addBatch': 5684,
#    'getBatch': 1,
#    'latestOffset': 1,
#    'queryPlanning': 95,
#    'triggerExecution': 5828,
#    'walCommit': 17},
#   'eventTime': {'watermark': '2021-10-18T15:36:13.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329728,
#     'customMetrics': {'loadedMapCacheHitCount': 82000,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1630}},
#     'endOffset': {'RoboticArm': {'0': 1633}},
#     'numInputRows': 6,
#     'inputRowsPerSecond': 0.9858692080184028,
#     'processedRowsPerSecond': 1.029512697323267}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:37:16.498Z',
#   'batchId': 206,
#   'numInputRows': 8,
#   'inputRowsPerSecond': 1.372448104306056,
#   'processedRowsPerSecond': 1.3297872340425532,
#   'durationMs': {'addBatch': 5848,
#    'getBatch': 1,
#    'latestOffset': 1,
#    'queryPlanning': 121,
#    'triggerExecution': 6016,
#    'walCommit': 22},
#   'eventTime': {'avg': '2021-10-18T15:37:13.000Z',
#    'max': '2021-10-18T15:37:13.000Z',
#    'min': '2021-10-18T15:37:13.000Z',
#    'watermark': '2021-10-18T15:36:13.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330016,
#     'customMetrics': {'loadedMapCacheHitCount': 82400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1633}},
#     'endOffset': {'RoboticArm': {'0': 1637}},
#     'numInputRows': 8,
#     'inputRowsPerSecond': 1.372448104306056,
#     'processedRowsPerSecond': 1.3297872340425532}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:37:22.515Z',
#   'batchId': 207,
#   'numInputRows': 2,
#   'inputRowsPerSecond': 0.3323915572544457,
#   'processedRowsPerSecond': 0.3058103975535168,
#   'durationMs': {'addBatch': 6357,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 128,
#    'triggerExecution': 6540,
#    'walCommit': 26},
#   'eventTime': {'avg': '2021-10-18T15:37:16.000Z',
#    'max': '2021-10-18T15:37:16.000Z',
#    'min': '2021-10-18T15:37:16.000Z',
#    'watermark': '2021-10-18T15:36:23.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330832,
#     'customMetrics': {'loadedMapCacheHitCount': 82800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37064}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1637}},
#     'endOffset': {'RoboticArm': {'0': 1638}},
#     'numInputRows': 2,
#     'inputRowsPerSecond': 0.3323915572544457,
#     'processedRowsPerSecond': 0.3058103975535168}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:37:29.057Z',
#   'batchId': 208,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.6114338122898196,
#   'processedRowsPerSecond': 0.6594131223211342,
#   'durationMs': {'addBatch': 5897,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 119,
#    'triggerExecution': 6066,
#    'walCommit': 25},
#   'eventTime': {'avg': '2021-10-18T15:37:27.000Z',
#    'max': '2021-10-18T15:37:27.000Z',
#    'min': '2021-10-18T15:37:27.000Z',
#    'watermark': '2021-10-18T15:36:23.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330344,
#     'customMetrics': {'loadedMapCacheHitCount': 83200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1638}},
#     'endOffset': {'RoboticArm': {'0': 1640}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.6114338122898196,
#     'processedRowsPerSecond': 0.6594131223211342}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:37:35.124Z',
#   'batchId': 209,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.6593044338223174,
#   'processedRowsPerSecond': 0.5557871335278588,
#   'durationMs': {'addBatch': 7005,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 130,
#    'triggerExecution': 7197,
#    'walCommit': 25},
#   'eventTime': {'watermark': '2021-10-18T15:36:46.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330176,
#     'customMetrics': {'loadedMapCacheHitCount': 83600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37312}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1640}},
#     'endOffset': {'RoboticArm': {'0': 1642}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.6593044338223174,
#     'processedRowsPerSecond': 0.5557871335278588}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:37:42.322Z',
#   'batchId': 210,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5557099194220616,
#   'processedRowsPerSecond': 0.5932957579353307,
#   'durationMs': {'addBatch': 6542,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 114,
#    'triggerExecution': 6742,
#    'walCommit': 40},
#   'eventTime': {'watermark': '2021-10-18T15:36:46.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329728,
#     'customMetrics': {'loadedMapCacheHitCount': 84000,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1642}},
#     'endOffset': {'RoboticArm': {'0': 1644}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5557099194220616,
#     'processedRowsPerSecond': 0.5932957579353307}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:37:49.065Z',
#   'batchId': 211,
#   'numInputRows': 8,
#   'inputRowsPerSecond': 1.1864155420436007,
#   'processedRowsPerSecond': 1.0866612333605,
#   'durationMs': {'addBatch': 7197,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 123,
#    'triggerExecution': 7362,
#    'walCommit': 23},
#   'eventTime': {'avg': '2021-10-18T15:37:47.000Z',
#    'max': '2021-10-18T15:37:47.000Z',
#    'min': '2021-10-18T15:37:47.000Z',
#    'watermark': '2021-10-18T15:36:46.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330016,
#     'customMetrics': {'loadedMapCacheHitCount': 84400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1644}},
#     'endOffset': {'RoboticArm': {'0': 1648}},
#     'numInputRows': 8,
#     'inputRowsPerSecond': 1.1864155420436007,
#     'processedRowsPerSecond': 1.0866612333605}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:37:56.428Z',
#   'batchId': 212,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5432568246638598,
#   'processedRowsPerSecond': 0.5926803970958661,
#   'durationMs': {'addBatch': 6568,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 128,
#    'triggerExecution': 6749,
#    'walCommit': 27},
#   'eventTime': {'avg': '2021-10-18T15:37:50.000Z',
#    'max': '2021-10-18T15:37:50.000Z',
#    'min': '2021-10-18T15:37:50.000Z',
#    'watermark': '2021-10-18T15:36:57.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330832,
#     'customMetrics': {'loadedMapCacheHitCount': 84800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37064}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1648}},
#     'endOffset': {'RoboticArm': {'0': 1650}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5432568246638598,
#     'processedRowsPerSecond': 0.5926803970958661}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:38:03.178Z',
#   'batchId': 213,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5925925925925926,
#   'processedRowsPerSecond': 0.6232471174820816,
#   'durationMs': {'addBatch': 6249,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 124,
#    'triggerExecution': 6418,
#    'walCommit': 29},
#   'eventTime': {'avg': '2021-10-18T15:38:00.000Z',
#    'max': '2021-10-18T15:38:00.000Z',
#    'min': '2021-10-18T15:38:00.000Z',
#    'watermark': '2021-10-18T15:36:57.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330344,
#     'customMetrics': {'loadedMapCacheHitCount': 85200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1650}},
#     'endOffset': {'RoboticArm': {'0': 1652}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5925925925925926,
#     'processedRowsPerSecond': 0.6232471174820816}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:38:09.597Z',
#   'batchId': 214,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.6231500233681259,
#   'processedRowsPerSecond': 0.5156632718834602,
#   'durationMs': {'addBatch': 7618,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 99,
#    'triggerExecution': 7756,
#    'walCommit': 19},
#   'eventTime': {'watermark': '2021-10-18T15:37:20.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330176,
#     'customMetrics': {'loadedMapCacheHitCount': 85600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37312}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1652}},
#     'endOffset': {'RoboticArm': {'0': 1654}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.6231500233681259,
#     'processedRowsPerSecond': 0.5156632718834602}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:38:17.354Z',
#   'batchId': 215,
#   'numInputRows': 6,
#   'inputRowsPerSecond': 0.7734949078251901,
#   'processedRowsPerSecond': 0.7801326225458328,
#   'durationMs': {'addBatch': 7510,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 126,
#    'triggerExecution': 7691,
#    'walCommit': 26},
#   'eventTime': {'watermark': '2021-10-18T15:37:20.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329728,
#     'customMetrics': {'loadedMapCacheHitCount': 86000,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1654}},
#     'endOffset': {'RoboticArm': {'0': 1657}},
#     'numInputRows': 6,
#     'inputRowsPerSecond': 0.7734949078251901,
#     'processedRowsPerSecond': 0.7801326225458328}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:38:25.046Z',
#   'batchId': 216,
#   'numInputRows': 10,
#   'inputRowsPerSecond': 1.3000520020800832,
#   'processedRowsPerSecond': 1.3317352510320948,
#   'durationMs': {'addBatch': 7334,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 122,
#    'triggerExecution': 7509,
#    'walCommit': 26},
#   'eventTime': {'avg': '2021-10-18T15:38:21.500Z',
#    'max': '2021-10-18T15:38:23.000Z',
#    'min': '2021-10-18T15:38:20.000Z',
#    'watermark': '2021-10-18T15:37:20.000Z'},
#   'stateOperators': [{'numRowsTotal': 10,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330336,
#     'customMetrics': {'loadedMapCacheHitCount': 86400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37776}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1657}},
#     'endOffset': {'RoboticArm': {'0': 1662}},
#     'numInputRows': 10,
#     'inputRowsPerSecond': 1.3000520020800832,
#     'processedRowsPerSecond': 1.3317352510320948}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:38:32.556Z',
#   'batchId': 217,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 6723,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 107,
#    'triggerExecution': 6875,
#    'walCommit': 27},
#   'eventTime': {'watermark': '2021-10-18T15:37:30.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330824,
#     'customMetrics': {'loadedMapCacheHitCount': 86800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37096}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1662}},
#     'endOffset': {'RoboticArm': {'0': 1662}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:38:39.431Z',
#   'batchId': 218,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5818181818181818,
#   'processedRowsPerSecond': 0.5483959418700302,
#   'durationMs': {'addBatch': 7136,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 100,
#    'triggerExecution': 7294,
#    'walCommit': 20},
#   'eventTime': {'avg': '2021-10-18T15:38:33.000Z',
#    'max': '2021-10-18T15:38:33.000Z',
#    'min': '2021-10-18T15:38:33.000Z',
#    'watermark': '2021-10-18T15:37:30.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330376,
#     'customMetrics': {'loadedMapCacheHitCount': 87200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1662}},
#     'endOffset': {'RoboticArm': {'0': 1664}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5818181818181818,
#     'processedRowsPerSecond': 0.5483959418700302}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:38:46.726Z',
#   'batchId': 219,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5483207676490747,
#   'processedRowsPerSecond': 0.5864242779651078,
#   'durationMs': {'addBatch': 6657,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 121,
#    'triggerExecution': 6821,
#    'walCommit': 26},
#   'eventTime': {'watermark': '2021-10-18T15:37:53.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330176,
#     'customMetrics': {'loadedMapCacheHitCount': 87600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37312}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1664}},
#     'endOffset': {'RoboticArm': {'0': 1666}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5483207676490747,
#     'processedRowsPerSecond': 0.5864242779651078}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:38:53.548Z',
#   'batchId': 220,
#   'numInputRows': 12,
#   'inputRowsPerSecond': 1.7590149516270888,
#   'processedRowsPerSecond': 1.9455252918287937,
#   'durationMs': {'addBatch': 6032,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 96,
#    'triggerExecution': 6168,
#    'walCommit': 17},
#   'eventTime': {'avg': '2021-10-18T15:38:53.000Z',
#    'max': '2021-10-18T15:38:53.000Z',
#    'min': '2021-10-18T15:38:53.000Z',
#    'watermark': '2021-10-18T15:37:53.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330048,
#     'customMetrics': {'loadedMapCacheHitCount': 88000,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1666}},
#     'endOffset': {'RoboticArm': {'0': 1672}},
#     'numInputRows': 12,
#     'inputRowsPerSecond': 1.7590149516270888,
#     'processedRowsPerSecond': 1.9455252918287937}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:38:59.717Z',
#   'batchId': 221,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.648403306856865,
#   'processedRowsPerSecond': 0.604138347681619,
#   'durationMs': {'addBatch': 6436,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 128,
#    'triggerExecution': 6621,
#    'walCommit': 26},
#   'eventTime': {'avg': '2021-10-18T15:38:56.000Z',
#    'max': '2021-10-18T15:38:56.000Z',
#    'min': '2021-10-18T15:38:56.000Z',
#    'watermark': '2021-10-18T15:38:03.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330832,
#     'customMetrics': {'loadedMapCacheHitCount': 88400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37064}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1672}},
#     'endOffset': {'RoboticArm': {'0': 1674}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.648403306856865,
#     'processedRowsPerSecond': 0.604138347681619}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:39:06.408Z',
#   'batchId': 222,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 363.6363636363637,
#   'processedRowsPerSecond': 0.5846243788365976,
#   'durationMs': {'addBatch': 6666,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 120,
#    'triggerExecution': 6842,
#    'walCommit': 32},
#   'eventTime': {'avg': '2021-10-18T15:39:06.000Z',
#    'max': '2021-10-18T15:39:06.000Z',
#    'min': '2021-10-18T15:39:06.000Z',
#    'watermark': '2021-10-18T15:38:03.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330344,
#     'customMetrics': {'loadedMapCacheHitCount': 88800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1674}},
#     'endOffset': {'RoboticArm': {'0': 1676}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 363.6363636363637,
#     'processedRowsPerSecond': 0.5846243788365976}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:39:13.251Z',
#   'batchId': 223,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 4308,
#    'getBatch': 0,
#    'latestOffset': 2,
#    'queryPlanning': 117,
#    'triggerExecution': 4476,
#    'walCommit': 28},
#   'eventTime': {'watermark': '2021-10-18T15:38:26.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330176,
#     'customMetrics': {'loadedMapCacheHitCount': 89200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37312}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1676}},
#     'endOffset': {'RoboticArm': {'0': 1676}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:39:17.728Z',
#   'batchId': 224,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.8934554389099844,
#   'processedRowsPerSecond': 0.6377551020408163,
#   'durationMs': {'addBatch': 6100,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 124,
#    'triggerExecution': 6272,
#    'walCommit': 26},
#   'eventTime': {'watermark': '2021-10-18T15:38:26.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329728,
#     'customMetrics': {'loadedMapCacheHitCount': 89600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1676}},
#     'endOffset': {'RoboticArm': {'0': 1678}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.8934554389099844,
#     'processedRowsPerSecond': 0.6377551020408163}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:39:24.001Z',
#   'batchId': 225,
#   'numInputRows': 6,
#   'inputRowsPerSecond': 0.9564801530368245,
#   'processedRowsPerSecond': 0.9721322099805574,
#   'durationMs': {'addBatch': 5987,
#    'getBatch': 1,
#    'latestOffset': 1,
#    'queryPlanning': 140,
#    'triggerExecution': 6172,
#    'walCommit': 31},
#   'eventTime': {'watermark': '2021-10-18T15:38:26.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329696,
#     'customMetrics': {'loadedMapCacheHitCount': 90000,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1678}},
#     'endOffset': {'RoboticArm': {'0': 1681}},
#     'numInputRows': 6,
#     'inputRowsPerSecond': 0.9564801530368245,
#     'processedRowsPerSecond': 0.9721322099805574}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:39:30.174Z',
#   'batchId': 226,
#   'numInputRows': 10,
#   'inputRowsPerSecond': 1.6199578810950914,
#   'processedRowsPerSecond': 1.5451174289245981,
#   'durationMs': {'addBatch': 6316,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 122,
#    'triggerExecution': 6472,
#    'walCommit': 18},
#   'eventTime': {'avg': '2021-10-18T15:39:27.500Z',
#    'max': '2021-10-18T15:39:29.000Z',
#    'min': '2021-10-18T15:39:26.000Z',
#    'watermark': '2021-10-18T15:38:26.000Z'},
#   'stateOperators': [{'numRowsTotal': 10,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330336,
#     'customMetrics': {'loadedMapCacheHitCount': 90400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37776}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1681}},
#     'endOffset': {'RoboticArm': {'0': 1686}},
#     'numInputRows': 10,
#     'inputRowsPerSecond': 1.6199578810950914,
#     'processedRowsPerSecond': 1.5451174289245981}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:39:36.646Z',
#   'batchId': 227,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 6939,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 102,
#    'triggerExecution': 7093,
#    'walCommit': 20},
#   'eventTime': {'watermark': '2021-10-18T15:38:36.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330824,
#     'customMetrics': {'loadedMapCacheHitCount': 90800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37096}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1686}},
#     'endOffset': {'RoboticArm': {'0': 1686}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:39:43.739Z',
#   'batchId': 228,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5639362752009023,
#   'processedRowsPerSecond': 0.5851375073142188,
#   'durationMs': {'addBatch': 6664,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 121,
#    'triggerExecution': 6836,
#    'walCommit': 32},
#   'eventTime': {'avg': '2021-10-18T15:39:39.000Z',
#    'max': '2021-10-18T15:39:39.000Z',
#    'min': '2021-10-18T15:39:39.000Z',
#    'watermark': '2021-10-18T15:38:36.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330376,
#     'customMetrics': {'loadedMapCacheHitCount': 91200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1686}},
#     'endOffset': {'RoboticArm': {'0': 1688}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5639362752009023,
#     'processedRowsPerSecond': 0.5851375073142188}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:39:50.576Z',
#   'batchId': 229,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5850519233581981,
#   'processedRowsPerSecond': 0.5592841163310962,
#   'durationMs': {'addBatch': 7008,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 108,
#    'triggerExecution': 7152,
#    'walCommit': 19},
#   'eventTime': {'watermark': '2021-10-18T15:38:59.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330176,
#     'customMetrics': {'loadedMapCacheHitCount': 91600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37312}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1688}},
#     'endOffset': {'RoboticArm': {'0': 1690}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5850519233581981,
#     'processedRowsPerSecond': 0.5592841163310962}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:39:57.729Z',
#   'batchId': 230,
#   'numInputRows': 8,
#   'inputRowsPerSecond': 1.1184118551656648,
#   'processedRowsPerSecond': 1.1066537557061835,
#   'durationMs': {'addBatch': 7085,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 94,
#    'triggerExecution': 7229,
#    'walCommit': 19},
#   'eventTime': {'watermark': '2021-10-18T15:38:59.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329728,
#     'customMetrics': {'loadedMapCacheHitCount': 92000,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1690}},
#     'endOffset': {'RoboticArm': {'0': 1694}},
#     'numInputRows': 8,
#     'inputRowsPerSecond': 1.1184118551656648,
#     'processedRowsPerSecond': 1.1066537557061835}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:40:04.959Z',
#   'batchId': 231,
#   'numInputRows': 8,
#   'inputRowsPerSecond': 1.106500691562932,
#   'processedRowsPerSecond': 1.1182555213866368,
#   'durationMs': {'addBatch': 6993,
#    'getBatch': 1,
#    'latestOffset': 1,
#    'queryPlanning': 106,
#    'triggerExecution': 7154,
#    'walCommit': 28},
#   'eventTime': {'avg': '2021-10-18T15:40:00.500Z',
#    'max': '2021-10-18T15:40:02.000Z',
#    'min': '2021-10-18T15:39:59.000Z',
#    'watermark': '2021-10-18T15:38:59.000Z'},
#   'stateOperators': [{'numRowsTotal': 10,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330336,
#     'customMetrics': {'loadedMapCacheHitCount': 92400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37776}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1694}},
#     'endOffset': {'RoboticArm': {'0': 1698}},
#     'numInputRows': 8,
#     'inputRowsPerSecond': 1.106500691562932,
#     'processedRowsPerSecond': 1.1182555213866368}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:40:12.114Z',
#   'batchId': 232,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 6813,
#    'getBatch': 1,
#    'latestOffset': 1,
#    'queryPlanning': 115,
#    'triggerExecution': 6989,
#    'walCommit': 29},
#   'eventTime': {'watermark': '2021-10-18T15:39:09.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330824,
#     'customMetrics': {'loadedMapCacheHitCount': 92800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37096}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1698}},
#     'endOffset': {'RoboticArm': {'0': 1698}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:40:19.103Z',
#   'batchId': 233,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5723279439118615,
#   'processedRowsPerSecond': 0.6299212598425197,
#   'durationMs': {'addBatch': 6175,
#    'getBatch': 2,
#    'latestOffset': 1,
#    'queryPlanning': 127,
#    'triggerExecution': 6350,
#    'walCommit': 22},
#   'eventTime': {'avg': '2021-10-18T15:40:12.000Z',
#    'max': '2021-10-18T15:40:12.000Z',
#    'min': '2021-10-18T15:40:12.000Z',
#    'watermark': '2021-10-18T15:39:09.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330376,
#     'customMetrics': {'loadedMapCacheHitCount': 93200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1698}},
#     'endOffset': {'RoboticArm': {'0': 1700}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5723279439118615,
#     'processedRowsPerSecond': 0.6299212598425197}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:40:25.454Z',
#   'batchId': 234,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.629822075263738,
#   'processedRowsPerSecond': 0.5148667782211352,
#   'durationMs': {'addBatch': 7577,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 133,
#    'triggerExecution': 7769,
#    'walCommit': 37},
#   'eventTime': {'watermark': '2021-10-18T15:39:32.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330176,
#     'customMetrics': {'loadedMapCacheHitCount': 93600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37312}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1700}},
#     'endOffset': {'RoboticArm': {'0': 1702}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.629822075263738,
#     'processedRowsPerSecond': 0.5148667782211352}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:40:33.225Z',
#   'batchId': 235,
#   'numInputRows': 12,
#   'inputRowsPerSecond': 1.544202805301763,
#   'processedRowsPerSecond': 1.6308779559662954,
#   'durationMs': {'addBatch': 7184,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 116,
#    'triggerExecution': 7358,
#    'walCommit': 28},
#   'eventTime': {'avg': '2021-10-18T15:40:32.000Z',
#    'max': '2021-10-18T15:40:32.000Z',
#    'min': '2021-10-18T15:40:32.000Z',
#    'watermark': '2021-10-18T15:39:32.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330048,
#     'customMetrics': {'loadedMapCacheHitCount': 94000,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1702}},
#     'endOffset': {'RoboticArm': {'0': 1708}},
#     'numInputRows': 12,
#     'inputRowsPerSecond': 1.544202805301763,
#     'processedRowsPerSecond': 1.6308779559662954}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:40:40.584Z',
#   'batchId': 236,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5435521130588395,
#   'processedRowsPerSecond': 0.5465227490094275,
#   'durationMs': {'addBatch': 7120,
#    'getBatch': 0,
#    'latestOffset': 2,
#    'queryPlanning': 145,
#    'triggerExecution': 7319,
#    'walCommit': 32},
#   'eventTime': {'avg': '2021-10-18T15:40:35.000Z',
#    'max': '2021-10-18T15:40:35.000Z',
#    'min': '2021-10-18T15:40:35.000Z',
#    'watermark': '2021-10-18T15:39:42.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330832,
#     'customMetrics': {'loadedMapCacheHitCount': 94400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37064}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1708}},
#     'endOffset': {'RoboticArm': {'0': 1710}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5435521130588395,
#     'processedRowsPerSecond': 0.5465227490094275}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:40:47.905Z',
#   'batchId': 237,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5463734462505122,
#   'processedRowsPerSecond': 0.5644137152532807,
#   'durationMs': {'addBatch': 6917,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 122,
#    'triggerExecution': 7087,
#    'walCommit': 28},
#   'eventTime': {'avg': '2021-10-18T15:40:45.000Z',
#    'max': '2021-10-18T15:40:45.000Z',
#    'min': '2021-10-18T15:40:45.000Z',
#    'watermark': '2021-10-18T15:39:42.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330344,
#     'customMetrics': {'loadedMapCacheHitCount': 94800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1710}},
#     'endOffset': {'RoboticArm': {'0': 1712}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5463734462505122,
#     'processedRowsPerSecond': 0.5644137152532807}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:40:54.993Z',
#   'batchId': 238,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5643340857787811,
#   'processedRowsPerSecond': 0.5922416345869115,
#   'durationMs': {'addBatch': 6572,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 125,
#    'triggerExecution': 6754,
#    'walCommit': 27},
#   'eventTime': {'watermark': '2021-10-18T15:40:05.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330176,
#     'customMetrics': {'loadedMapCacheHitCount': 95200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37312}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1712}},
#     'endOffset': {'RoboticArm': {'0': 1714}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5643340857787811,
#     'processedRowsPerSecond': 0.5922416345869115}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:41:01.748Z',
#   'batchId': 239,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5921539600296077,
#   'processedRowsPerSecond': 0.6020469596628537,
#   'durationMs': {'addBatch': 6456,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 134,
#    'triggerExecution': 6644,
#    'walCommit': 32},
#   'eventTime': {'watermark': '2021-10-18T15:40:05.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329728,
#     'customMetrics': {'loadedMapCacheHitCount': 95600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1714}},
#     'endOffset': {'RoboticArm': {'0': 1716}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5921539600296077,
#     'processedRowsPerSecond': 0.6020469596628537}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:41:08.393Z',
#   'batchId': 240,
#   'numInputRows': 10,
#   'inputRowsPerSecond': 1.5048908954100828,
#   'processedRowsPerSecond': 1.545595054095827,
#   'durationMs': {'addBatch': 6288,
#    'getBatch': 1,
#    'latestOffset': 1,
#    'queryPlanning': 122,
#    'triggerExecution': 6470,
#    'walCommit': 32},
#   'eventTime': {'avg': '2021-10-18T15:41:05.000Z',
#    'max': '2021-10-18T15:41:05.000Z',
#    'min': '2021-10-18T15:41:05.000Z',
#    'watermark': '2021-10-18T15:40:05.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330016,
#     'customMetrics': {'loadedMapCacheHitCount': 96000,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1716}},
#     'endOffset': {'RoboticArm': {'0': 1721}},
#     'numInputRows': 10,
#     'inputRowsPerSecond': 1.5048908954100828,
#     'processedRowsPerSecond': 1.545595054095827}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:41:14.863Z',
#   'batchId': 241,
#   'numInputRows': 2,
#   'inputRowsPerSecond': 0.3091190108191654,
#   'processedRowsPerSecond': 0.29590176061547563,
#   'durationMs': {'addBatch': 6576,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 126,
#    'triggerExecution': 6759,
#    'walCommit': 27},
#   'eventTime': {'avg': '2021-10-18T15:41:08.000Z',
#    'max': '2021-10-18T15:41:08.000Z',
#    'min': '2021-10-18T15:41:08.000Z',
#    'watermark': '2021-10-18T15:40:15.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330832,
#     'customMetrics': {'loadedMapCacheHitCount': 96400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37064}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1721}},
#     'endOffset': {'RoboticArm': {'0': 1722}},
#     'numInputRows': 2,
#     'inputRowsPerSecond': 0.3091190108191654,
#     'processedRowsPerSecond': 0.29590176061547563}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:41:21.623Z',
#   'batchId': 242,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.591715976331361,
#   'processedRowsPerSecond': 0.6066120715802245,
#   'durationMs': {'addBatch': 6421,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 118,
#    'triggerExecution': 6594,
#    'walCommit': 27},
#   'eventTime': {'avg': '2021-10-18T15:41:18.000Z',
#    'max': '2021-10-18T15:41:18.000Z',
#    'min': '2021-10-18T15:41:18.000Z',
#    'watermark': '2021-10-18T15:40:15.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330344,
#     'customMetrics': {'loadedMapCacheHitCount': 96800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1722}},
#     'endOffset': {'RoboticArm': {'0': 1724}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.591715976331361,
#     'processedRowsPerSecond': 0.6066120715802245}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:41:28.218Z',
#   'batchId': 243,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.6065200909780136,
# ...
#     'inputRowsPerSecond': 0.5621135469364812,
#     'processedRowsPerSecond': 0.5557871335278588}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:46:29.768Z',
#   'batchId': 286,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.5557871335278588,
#   'processedRowsPerSecond': 0.6017752369489995,
#   'durationMs': {'addBatch': 6446,
#    'getBatch': 1,
#    'latestOffset': 1,
#    'queryPlanning': 133,
#    'triggerExecution': 6647,
#    'walCommit': 44},
#   'eventTime': {'watermark': '2021-10-18T15:45:37.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330176,
#     'customMetrics': {'loadedMapCacheHitCount': 114400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37312}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1832}},
#     'endOffset': {'RoboticArm': {'0': 1834}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.5557871335278588,
#     'processedRowsPerSecond': 0.6017752369489995}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:46:36.416Z',
#   'batchId': 287,
#   'numInputRows': 8,
#   'inputRowsPerSecond': 1.203369434416366,
#   'processedRowsPerSecond': 1.0653882008256759,
#   'durationMs': {'addBatch': 7336,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 126,
#    'triggerExecution': 7509,
#    'walCommit': 27},
#   'eventTime': {'watermark': '2021-10-18T15:45:37.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329728,
#     'customMetrics': {'loadedMapCacheHitCount': 114800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1834}},
#     'endOffset': {'RoboticArm': {'0': 1838}},
#     'numInputRows': 8,
#     'inputRowsPerSecond': 1.203369434416366,
#     'processedRowsPerSecond': 1.0653882008256759}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:46:43.926Z',
#   'batchId': 288,
#   'numInputRows': 8,
#   'inputRowsPerSecond': 1.0652463382157125,
#   'processedRowsPerSecond': 1.1965300628178284,
#   'durationMs': {'addBatch': 6508,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 123,
#    'triggerExecution': 6686,
#    'walCommit': 27},
#   'eventTime': {'avg': '2021-10-18T15:46:38.500Z',
#    'max': '2021-10-18T15:46:40.000Z',
#    'min': '2021-10-18T15:46:37.000Z',
#    'watermark': '2021-10-18T15:45:37.000Z'},
#   'stateOperators': [{'numRowsTotal': 10,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330336,
#     'customMetrics': {'loadedMapCacheHitCount': 115200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37776}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1838}},
#     'endOffset': {'RoboticArm': {'0': 1842}},
#     'numInputRows': 8,
#     'inputRowsPerSecond': 1.0652463382157125,
#     'processedRowsPerSecond': 1.1965300628178284}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:46:50.613Z',
#   'batchId': 289,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.598175564528189,
#   'processedRowsPerSecond': 0.6201550387596899,
#   'durationMs': {'addBatch': 6272,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 122,
#    'triggerExecution': 6450,
#    'walCommit': 34},
#   'eventTime': {'avg': '2021-10-18T15:46:50.000Z',
#    'max': '2021-10-18T15:46:50.000Z',
#    'min': '2021-10-18T15:46:50.000Z',
#    'watermark': '2021-10-18T15:45:47.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 331016,
#     'customMetrics': {'loadedMapCacheHitCount': 115600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37592}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1842}},
#     'endOffset': {'RoboticArm': {'0': 1844}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.598175564528189,
#     'processedRowsPerSecond': 0.6201550387596899}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 2}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:46:57.064Z',
#   'batchId': 290,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 6293,
#    'getBatch': 0,
#    'latestOffset': 3,
#    'queryPlanning': 112,
#    'triggerExecution': 6453,
#    'walCommit': 29},
#   'eventTime': {'watermark': '2021-10-18T15:46:10.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330240,
#     'customMetrics': {'loadedMapCacheHitCount': 116000,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37312}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1844}},
#     'endOffset': {'RoboticArm': {'0': 1844}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:47:03.518Z',
#   'batchId': 291,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.6197706848466068,
#   'processedRowsPerSecond': 0.5747126436781609,
#   'durationMs': {'addBatch': 6826,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 101,
#    'triggerExecution': 6960,
#    'walCommit': 20},
#   'eventTime': {'watermark': '2021-10-18T15:46:10.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329728,
#     'customMetrics': {'loadedMapCacheHitCount': 116400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1844}},
#     'endOffset': {'RoboticArm': {'0': 1846}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.6197706848466068,
#     'processedRowsPerSecond': 0.5747126436781609}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:47:10.479Z',
#   'batchId': 292,
#   'numInputRows': 12,
#   'inputRowsPerSecond': 1.7238902456543599,
#   'processedRowsPerSecond': 1.9169329073482428,
#   'durationMs': {'addBatch': 6124,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 96,
#    'triggerExecution': 6260,
#    'walCommit': 16},
#   'eventTime': {'avg': '2021-10-18T15:47:10.000Z',
#    'max': '2021-10-18T15:47:10.000Z',
#    'min': '2021-10-18T15:47:10.000Z',
#    'watermark': '2021-10-18T15:46:10.000Z'},
#   'stateOperators': [{'numRowsTotal': 9,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330016,
#     'customMetrics': {'loadedMapCacheHitCount': 116800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37528}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1846}},
#     'endOffset': {'RoboticArm': {'0': 1852}},
#     'numInputRows': 12,
#     'inputRowsPerSecond': 1.7238902456543599,
#     'processedRowsPerSecond': 1.9169329073482428}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:47:16.740Z',
#   'batchId': 293,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 0.6388755789809935,
#   'processedRowsPerSecond': 0.6590871642774757,
#   'durationMs': {'addBatch': 5889,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 121,
#    'triggerExecution': 6069,
#    'walCommit': 36},
#   'eventTime': {'avg': '2021-10-18T15:47:13.000Z',
#    'max': '2021-10-18T15:47:13.000Z',
#    'min': '2021-10-18T15:47:13.000Z',
#    'watermark': '2021-10-18T15:46:20.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330576,
#     'customMetrics': {'loadedMapCacheHitCount': 117200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37064}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1852}},
#     'endOffset': {'RoboticArm': {'0': 1854}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 0.6388755789809935,
#     'processedRowsPerSecond': 0.6590871642774757}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:47:23.329Z',
#   'batchId': 294,
#   'numInputRows': 2,
#   'inputRowsPerSecond': 166.66666666666666,
#   'processedRowsPerSecond': 0.2947678703021371,
#   'durationMs': {'addBatch': 6604,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 120,
#    'triggerExecution': 6785,
#    'walCommit': 30},
#   'eventTime': {'avg': '2021-10-18T15:47:23.000Z',
#    'max': '2021-10-18T15:47:23.000Z',
#    'min': '2021-10-18T15:47:23.000Z',
#    'watermark': '2021-10-18T15:46:20.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 329888,
#     'customMetrics': {'loadedMapCacheHitCount': 117600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37272}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1854}},
#     'endOffset': {'RoboticArm': {'0': 1855}},
#     'numInputRows': 2,
#     'inputRowsPerSecond': 166.66666666666666,
#     'processedRowsPerSecond': 0.2947678703021371}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:47:30.115Z',
#   'batchId': 295,
#   'numInputRows': 2,
#   'inputRowsPerSecond': 0.29472443265546716,
#   'processedRowsPerSecond': 0.5027652086475616,
#   'durationMs': {'addBatch': 3823,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 109,
#    'triggerExecution': 3978,
#    'walCommit': 25},
#   'eventTime': {'avg': '2021-10-18T15:47:23.000Z',
#    'max': '2021-10-18T15:47:23.000Z',
#    'min': '2021-10-18T15:47:23.000Z',
#    'watermark': '2021-10-18T15:46:43.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 1,
#     'memoryUsedBytes': 330192,
#     'customMetrics': {'loadedMapCacheHitCount': 118000,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37296}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1855}},
#     'endOffset': {'RoboticArm': {'0': 1856}},
#     'numInputRows': 2,
#     'inputRowsPerSecond': 0.29472443265546716,
#     'processedRowsPerSecond': 0.5027652086475616}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:47:34.093Z',
#   'batchId': 296,
#   'numInputRows': 4,
#   'inputRowsPerSecond': 1.0055304172951232,
#   'processedRowsPerSecond': 0.5397382269599245,
#   'durationMs': {'addBatch': 7233,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 127,
#    'triggerExecution': 7411,
#    'walCommit': 25},
#   'eventTime': {'watermark': '2021-10-18T15:46:43.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329712,
#     'customMetrics': {'loadedMapCacheHitCount': 118400,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1856}},
#     'endOffset': {'RoboticArm': {'0': 1858}},
#     'numInputRows': 4,
#     'inputRowsPerSecond': 1.0055304172951232,
#     'processedRowsPerSecond': 0.5397382269599245}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:47:41.505Z',
#   'batchId': 297,
#   'numInputRows': 8,
#   'inputRowsPerSecond': 1.0793308148947653,
#   'processedRowsPerSecond': 1.1534025374855825,
#   'durationMs': {'addBatch': 6743,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 126,
#    'triggerExecution': 6936,
#    'walCommit': 43},
#   'eventTime': {'watermark': '2021-10-18T15:46:43.000Z'},
#   'stateOperators': [{'numRowsTotal': 8,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 329696,
#     'customMetrics': {'loadedMapCacheHitCount': 118800,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37280}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1858}},
#     'endOffset': {'RoboticArm': {'0': 1862}},
#     'numInputRows': 8,
#     'inputRowsPerSecond': 1.0793308148947653,
#     'processedRowsPerSecond': 1.1534025374855825}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:47:48.444Z',
#   'batchId': 298,
#   'numInputRows': 8,
#   'inputRowsPerSecond': 1.1529038766392852,
#   'processedRowsPerSecond': 1.0774410774410774,
#   'durationMs': {'addBatch': 7229,
#    'getBatch': 0,
#    'latestOffset': 1,
#    'queryPlanning': 140,
#    'triggerExecution': 7425,
#    'walCommit': 32},
#   'eventTime': {'avg': '2021-10-18T15:47:44.500Z',
#    'max': '2021-10-18T15:47:46.000Z',
#    'min': '2021-10-18T15:47:43.000Z',
#    'watermark': '2021-10-18T15:46:43.000Z'},
#   'stateOperators': [{'numRowsTotal': 10,
#     'numRowsUpdated': 2,
#     'memoryUsedBytes': 330336,
#     'customMetrics': {'loadedMapCacheHitCount': 119200,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37776}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1862}},
#     'endOffset': {'RoboticArm': {'0': 1866}},
#     'numInputRows': 8,
#     'inputRowsPerSecond': 1.1529038766392852,
#     'processedRowsPerSecond': 1.0774410774410774}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'd4b166a1-3bfd-4b96-b8b1-acfcb4f62d9e',
#   'runId': '63843925-e455-473e-8881-4486dfa2d89a',
#   'name': 'sinkTable',
#   'timestamp': '2021-10-18T15:47:55.870Z',
#   'batchId': 299,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 6815,
#    'getBatch': 0,
#    'latestOffset': 2,
#    'queryPlanning': 112,
#    'triggerExecution': 6994,
#    'walCommit': 34},
#   'eventTime': {'watermark': '2021-10-18T15:46:53.000Z'},
#   'stateOperators': [{'numRowsTotal': 7,
#     'numRowsUpdated': 0,
#     'memoryUsedBytes': 330824,
#     'customMetrics': {'loadedMapCacheHitCount': 119600,
#      'loadedMapCacheMissCount': 0,
#      'stateOnCurrentVersionSizeBytes': 37096}}],
#   'sources': [{'description': 'KafkaV2[Subscribe[RoboticArm]]',
#     'startOffset': {'RoboticArm': {'0': 1866}},
#     'endOffset': {'RoboticArm': {'0': 1866}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}}]

# %% [markdown]
# # E3.2
#
# Ora potete trovare un braccio in status goodGrasped sseguito dallo stesso braccio in status moving seguito dallo stesso braccio in status placing e restituire l'id del braccio e (stressLevelGoodGrasped+stressLevelMoving+stressLevelPlacing)/3 (che è la media degli stress level nei tre stati)

# %%
grasped_sdf = (RoboticArm_sdf
              .withWatermark("ts","1 minute")
               .where("status='goodGrasped'")
              .withColumnRenamed("id","idGrasped")
              .withColumnRenamed("status","statusGrasped")
              .withColumnRenamed("stressLevel","stressLevelGrasped")
              .withColumnRenamed("ts","tsGrasped")
              )

moving_sdf = (RoboticArm_sdf
              .withWatermark("ts","1 minute")
              .where("status='movingGood'")
              .withColumnRenamed("id","idMoving")
              .withColumnRenamed("status","statusMoving")
              .withColumnRenamed("stressLevel","stressLevelMoving")
              .withColumnRenamed("ts","tsMoving")
             )
placing_sdf = (RoboticArm_sdf
              .withWatermark("ts","1 minute")
               .where("status='placingGood'")
              .withColumnRenamed("id","idPlacing")
              .withColumnRenamed("status","statusPlacing")
              .withColumnRenamed("stressLevel","stressLevelPlacing")
              .withColumnRenamed("ts","tsPlacing")
              )

# %%
join1_sdf = grasped_sdf.join(moving_sdf,
                            expr("""
                            idMoving=idGrasped AND
                            tsMoving > tsGrasped AND
                            tsMoving <= tsGrasped + interval 5 seconds
                            """))

join2_sdf = join1_sdf.join(placing_sdf,
                            expr("""
                            idPlacing=idMoving AND
                            tsPlacing > tsMoving AND
                            tsPlacing <= tsMoving + interval 14 seconds
                            """))

# %%
prj_sdf = (join2_sdf.select(
                col("idPlacing").alias("ID"),
                expr("(stressLevelGrasped+stressLevelMoving+stressLevelPlacing)/3 AS avgStressLevel")
))

# %%
e32 = (prj_sdf
                     .writeStream
                     .format("memory")
                     #.outputMode("complete") # 
                     .queryName("sinkTable")
                     .start())

# %%
# look up the most recent results
spark.sql("SELECT ID, COUNT(*) FROM sinkTable GROUP BY ID").show(10)
# Out:
# +---+--------+
# | ID|count(1)|
# +---+--------+
# |  1|     164|
# |  2|     164|
# +---+--------+

# %%
e32.stop()
