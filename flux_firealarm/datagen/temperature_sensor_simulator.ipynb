# %%
# !pip install influxdb-client
# Out:
# Collecting influxdb-client
#   Downloading influxdb_client-1.23.0-py3-none-any.whl (522 kB)
#      |████████████████████████████████| 522 kB 4.0 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2020.6.20)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2.8.1)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (1.25.11)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (49.6.0.post20201009)
# Requirement already satisfied: pytz>=2019.1 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (2020.4)
# Collecting rx>=3.0.1
#   Downloading Rx-3.2.0-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 4.7 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.8/site-packages (from influxdb-client) (1.15.0)
# Installing collected packages: rx, influxdb-client
# Successfully installed influxdb-client-1.23.0 rx-3.2.0

# %%
from datetime import datetime


from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS

# You can generate a Token from the "Tokens Tab" in the UI
token = "d2VsY29tZQ=="
org = "sda"
bucket = "training"

client = InfluxDBClient(url="http://influxdb:8086", token=token)
write_api = client.write_api(write_options=SYNCHRONOUS)

# %% [markdown]
# ## run the following cell to demostrate that fire is not detected

# %%
from random import gauss
import time
from IPython.display import clear_output

while True:
    point = Point("TemperatureSensorEvent").tag("sensor", "S1").field("temperature", gauss(20, 1.0))
    print(point)
    write_api.write(bucket, org, point)
    time.sleep(1)
    clear_output(wait=True)
# Out:
# <influxdb_client.client.write.point.Point object at 0x7f75f47407c0>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ff7fcd3f904b> in <module>
#       7     print(point)
#       8     write_api.write(bucket, org, point)
# ----> 9     time.sleep(1)
#      10     clear_output(wait=True)
#
# KeyboardInterrupt:

# %% [markdown]
# ## run the following cell to demostrate to detect fire

# %%
while True:
    point = Point("TemperatureSensorEvent").tag("sensor", "S1").field("temperature", gauss(55, 1.0))
    print(point)
    write_api.write(bucket, org, point)
    time.sleep(1)    
    clear_output(wait=True)
# Out:
# <influxdb_client.client.write.point.Point object at 0x7f8403c33820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32a00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b322b0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32a00>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32a00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b322b0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b320a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8340>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c820>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a8d00>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32130>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b329a0>
# <influxdb_client.client.write.point.Point object at 0x7f84193a83a0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f10>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c970>
# ...
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33c40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33880>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33190>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33e20>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33d60>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33190>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33880>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33c40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33cd0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33e80>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33e50>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8403c33f10>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f84182ee250>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c850>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32f40>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c760>
# <influxdb_client.client.write.point.Point object at 0x7f8418b2c910>
# <influxdb_client.client.write.point.Point object at 0x7f8418b32fa0>

# %% [markdown]
# ## Close client

# %%
client.__del__()
