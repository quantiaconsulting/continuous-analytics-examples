# %%
# !pip install confluent_kafka
# Out:
# Requirement already satisfied: confluent_kafka in /opt/conda/lib/python3.8/site-packages (1.6.0)

# %%
from confluent_kafka.admin import AdminClient, NewTopic, NewPartitions
from confluent_kafka import KafkaException
import sys
from uuid import uuid4

# %%
bootstrap_server = "kafka:9092" # Brokers act as cluster entripoints

# %%
conf = {'bootstrap.servers': bootstrap_server}

# %%
a = AdminClient(conf)

# %%
md = a.list_topics(timeout=10)
print(" {} topics:".format(len(md.topics)))
for t in iter(md.topics.values()):
    if t.error is not None:
        errstr = ": {}".format(t.error)
    else:
        errstr = ""
    ##if not (str(t)).startswith("_"):
    print("  \"{}\" with {} partition(s){}".format(t, len(t.partitions), errstr))
# Out:
# ---------------------------------------------------------------------------
# KafkaException                            Traceback (most recent call last)
# <ipython-input-6-b41fe215311d> in <module>
# ----> 1 md = a.list_topics(timeout=10)
#       2 print(" {} topics:".format(len(md.topics)))
#       3 for t in iter(md.topics.values()):
#       4     if t.error is not None:
#       5         errstr = ": {}".format(t.error)
#
# KafkaException: KafkaError{code=_TRANSPORT,val=-195,str="Failed to get metadata: Local: Broker transport failure"}

# %%
#fs = a.create_topics([NewTopic("test1p", num_partitions=1, replication_factor=1)])

#for topic, f in fs.items():
#    try:
#        f.result()  # The result itself is None
#        print("Topic {} created".format(topic))
#    except Exception as e:
#        print("Failed to create topic {}: {}".format(topic, e))

# %%
from confluent_kafka import SerializingProducer
from confluent_kafka.serialization import *

import time

topic = "SmokeSensorEvent"

def delivery_report(err, msg):
    if err is not None:
        print("Failed to deliver message: {}".format(err))
    else:
        print("Produced record to topic {} partition [{}] @ offset {}"
              .format(msg.topic(), msg.partition(), msg.offset()))

# %%
producer_conf = {
        'bootstrap.servers': bootstrap_server,
        'key.serializer': StringSerializer('utf_8'),
        'value.serializer': StringSerializer('utf_8')
}

producer = SerializingProducer(producer_conf)

# %% [markdown]
# ## run the following cell to demostrate that fire is not detected

# %%
import json

while True:
    key = "S1"
    value = {"sensor": "S1","smoke": False,"ts":int(time.time())}
    producer.produce(topic=topic, value=json.dumps(value), key=key, on_delivery=delivery_report)
    print(value)
    producer.poll(1)
    time.sleep(10)
# Out:
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234762}
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234773}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 0
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234783}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 1
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234793}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 2
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234803}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 3
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234813}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 4
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234823}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 5
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234833}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 6
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234843}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 7
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234853}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 8
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234863}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 9
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234873}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 10
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234883}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 11
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234893}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 12
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234903}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 13
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234913}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 14
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234923}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 15
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234933}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 16
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234943}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 17
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234953}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 18
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234963}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 19
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234973}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 20
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234983}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 21
# {'sensor': 'S1', 'smoke': False, 'ts': 1606234993}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 22
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235003}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 23
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235013}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 24
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235023}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 25
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235033}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 26
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235043}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 27
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235053}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 28
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235063}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 29
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235073}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 30
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235083}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 31
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235093}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 32
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235103}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 33
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235113}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 34
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235123}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 35
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235133}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 36
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235143}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 37
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235153}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 38
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235163}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 39
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235173}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 40
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235183}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 41
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235193}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 42
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235203}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 43
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235213}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 44
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235223}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 45
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235233}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 46
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235243}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 47
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235253}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 48
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235263}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 49
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235273}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 50
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235283}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 51
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235293}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 52
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235303}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 53
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235313}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 54
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235323}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 55
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235333}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 56
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235343}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 57
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235353}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 58
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235363}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 59
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235373}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 60
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235383}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 61
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235393}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 62
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235403}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 63
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235413}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 64
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235423}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 65
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235433}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 66
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235443}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 67
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235453}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 68
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235463}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 69
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235473}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 70
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235483}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 71
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235493}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 72
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235503}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 73
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235513}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 74
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235523}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 75
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235533}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 76
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235543}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 77
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235553}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 78
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235563}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 79
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235573}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 80
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235583}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 81
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235593}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 82
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235603}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 83
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235613}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 84
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235623}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 85
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235633}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 86
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235643}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 87
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235653}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 88
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235663}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 89
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235673}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 90
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235683}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 91
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235693}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 92
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235703}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 93
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235713}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 94
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235723}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 95
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235733}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 96
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235743}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 97
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235753}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 98
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235763}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 99
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235773}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 100
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235783}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 101
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235793}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 102
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235803}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 103
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235813}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 104
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235823}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 105
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235833}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 106
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235843}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 107
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235853}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 108
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235863}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 109
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235873}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 110
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235884}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 111
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235894}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 112
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235904}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 113
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235914}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 114
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235924}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 115
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235934}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 116
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235944}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 117
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235954}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 118
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235964}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 119
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235974}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 120
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235984}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 121
# {'sensor': 'S1', 'smoke': False, 'ts': 1606235994}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 122
# {'sensor': 'S1', 'smoke': False, 'ts': 1606236004}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 123
# {'sensor': 'S1', 'smoke': False, 'ts': 1606236014}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 124
# {'sensor': 'S1', 'smoke': False, 'ts': 1606236024}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d5de04644bfb> in <module>
#       7     print(value)
#       8     producer.poll(1)
# ----> 9     time.sleep(10)
#
# KeyboardInterrupt:

# %% [markdown]
# ## run the following cell to demostrate to detect fire

# %%
while True:
    key = "S1"
    value = {"sensor": "S1","smoke": True,"ts":int(time.time())}
    producer.produce(topic=topic, value=json.dumps(value), key=key, on_delivery=delivery_report)
    print(value)
    producer.poll(1)
    time.sleep(10)
# Out:
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236039}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 126
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236049}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 127
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236059}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 128
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236069}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 129
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236079}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 130
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236089}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 131
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236099}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 132
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236109}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 133
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236119}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 134
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236129}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 135
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236139}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 136
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236149}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 137
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236159}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 138
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236169}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 139
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236180}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 140
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236190}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 141
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236200}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 142
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236210}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 143
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236220}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 144
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236230}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 145
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236240}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 146
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236250}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 147
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236260}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 148
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236270}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 149
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236280}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 150
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236290}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 151
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236300}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 152
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236310}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 153
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236320}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 154
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236330}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 155
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236340}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 156
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236350}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 157
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236360}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 158
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236370}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 159
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236380}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 160
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236390}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 161
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236400}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 162
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236410}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 163
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236420}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 164
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236430}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 165
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236440}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 166
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236450}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 167
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236460}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 168
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236470}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 169
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236480}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 170
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236490}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 171
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236500}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 172
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236510}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 173
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236520}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 174
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236530}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 175
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236540}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 176
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236550}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 177
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236560}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 178
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236570}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 179
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236580}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 180
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236590}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 181
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236600}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 182
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236610}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 183
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236620}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 184
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236630}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 185
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236640}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 186
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236650}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 187
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236660}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 188
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236670}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 189
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236680}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 190
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236690}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 191
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236700}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 192
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236710}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 193
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236720}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 194
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236730}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 195
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236740}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 196
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236750}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 197
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236760}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 198
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236770}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 199
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236780}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 200
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236790}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 201
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236800}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 202
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236810}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 203
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236820}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 204
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236830}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 205
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236840}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 206
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236850}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 207
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236860}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 208
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236870}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 209
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236880}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 210
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236890}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 211
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236900}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 212
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236910}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 213
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236920}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 214
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236930}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 215
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236940}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 216
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236950}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 217
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236960}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 218
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236970}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 219
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236980}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 220
# {'sensor': 'S1', 'smoke': True, 'ts': 1606236990}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 221
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237000}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 222
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237010}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 223
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237020}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 224
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237030}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 225
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237040}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 226
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237050}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 227
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237060}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 228
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237070}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 229
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237080}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 230
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237090}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 231
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237100}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 232
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237110}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 233
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237120}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 234
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237130}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 235
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237140}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 236
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237150}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 237
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237160}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 238
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237170}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 239
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237180}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 240
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237190}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 241
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237200}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 242
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237210}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 243
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237220}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 244
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237230}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 245
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237240}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 246
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237250}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 247
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237260}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 248
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237270}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 249
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237280}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 250
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237290}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 251
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237300}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 252
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237310}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 253
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237320}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 254
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237330}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 255
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237340}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 256
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237350}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 257
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237360}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 258
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237370}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 259
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237380}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 260
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237391}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 261
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237401}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 262
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237411}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 263
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237421}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 264
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237431}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 265
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237441}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 266
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237451}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 267
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237461}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 268
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237471}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 269
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237481}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 270
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237491}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 271
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237501}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 272
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237511}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 273
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237521}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 274
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237531}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 275
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237541}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 276
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237551}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 277
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237561}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 278
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237571}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 279
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237581}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 280
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237591}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 281
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237601}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 282
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237611}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 283
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237621}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 284
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237631}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 285
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237641}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 286
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237651}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 287
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237661}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 288
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237671}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 289
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237681}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 290
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237691}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 291
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237701}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 292
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237711}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 293
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237721}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 294
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237731}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 295
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237741}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 296
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237751}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 297
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237761}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 298
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237771}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 299
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237781}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 300
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237791}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 301
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237801}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 302
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237811}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 303
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237821}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 304
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237831}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 305
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237841}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 306
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237851}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 307
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237861}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 308
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237871}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 309
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237881}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 310
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237891}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 311
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237901}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 312
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237911}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 313
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237921}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 314
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237931}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 315
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237941}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 316
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237951}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 317
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237961}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 318
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237971}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 319
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237981}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 320
# {'sensor': 'S1', 'smoke': True, 'ts': 1606237991}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 321
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238001}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 322
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238011}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 323
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238021}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 324
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238031}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 325
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238041}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 326
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238051}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 327
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238061}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 328
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238071}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 329
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238081}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 330
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238091}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 331
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238101}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 332
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238111}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 333
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238121}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 334
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238131}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 335
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238141}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 336
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238151}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 337
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238161}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 338
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238171}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 339
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238181}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 340
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238191}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 341
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238201}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 342
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238211}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 343
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238221}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 344
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238231}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 345
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238241}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 346
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238251}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 347
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238261}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 348
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238271}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 349
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238281}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 350
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238291}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 351
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238301}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 352
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238311}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 353
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238321}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 354
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238331}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 355
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238341}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 356
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238351}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 357
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238361}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 358
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238371}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 359
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238381}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 360
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238391}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 361
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238401}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 362
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238411}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 363
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238421}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 364
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238431}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 365
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238441}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 366
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238451}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 367
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238461}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 368
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238471}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 369
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238481}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 370
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238491}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 371
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238501}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 372
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238511}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 373
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238521}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 374
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238531}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 375
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238541}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 376
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238551}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 377
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238561}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 378
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238571}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 379
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238581}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 380
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238592}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 381
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238602}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 382
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238612}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 383
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238622}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 384
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238632}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 385
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238642}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 386
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238652}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 387
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238662}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 388
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238672}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 389
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238682}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 390
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238692}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 391
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238702}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 392
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238712}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 393
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238722}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 394
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238732}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 395
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238742}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 396
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238752}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 397
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238762}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 398
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238772}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 399
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238782}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 400
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238792}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 401
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238802}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 402
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238812}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 403
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238822}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 404
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238832}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 405
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238842}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 406
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238852}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 407
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238862}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 408
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238872}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 409
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238882}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 410
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238892}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 411
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238902}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 412
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238912}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 413
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238922}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 414
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238932}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 415
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238942}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 416
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238952}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 417
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238962}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 418
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238972}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 419
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238982}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 420
# {'sensor': 'S1', 'smoke': True, 'ts': 1606238992}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 421
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239002}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 422
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239012}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 423
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239022}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 424
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239032}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 425
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239042}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 426
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239052}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 427
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239062}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 428
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239072}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 429
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239082}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 430
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239092}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 431
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239102}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 432
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239112}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 433
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239122}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 434
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239132}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 435
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239142}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 436
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239152}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 437
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239162}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 438
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239172}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 439
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239182}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 440
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239192}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 441
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239202}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 442
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239212}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 443
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239222}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 444
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239232}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 445
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239242}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 446
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239252}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 447
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239262}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 448
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239272}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 449
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239282}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 450
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239292}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 451
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239302}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 452
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239312}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 453
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239322}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 454
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239332}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 455
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239342}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 456
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239352}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 457
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239362}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 458
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239372}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 459
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239382}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 460
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239392}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 461
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239402}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 462
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239412}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 463
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239422}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 464
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239432}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 465
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239442}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 466
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239452}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 467
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239462}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 468
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239472}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 469
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239482}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 470
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239492}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 471
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239502}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 472
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239512}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 473
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239522}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 474
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239532}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 475
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239542}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 476
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239552}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 477
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239562}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 478
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239572}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 479
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239582}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 480
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239592}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 481
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239602}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 482
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239612}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 483
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239622}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 484
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239632}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 485
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239642}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 486
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239652}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 487
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239662}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 488
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239672}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 489
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239682}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 490
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239692}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 491
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239702}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 492
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239712}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 493
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239722}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 494
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239732}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 495
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239742}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 496
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239752}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 497
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239763}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 498
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239773}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 499
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239783}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 500
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239793}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 501
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239803}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 502
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239813}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 503
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239823}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 504
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239833}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 505
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239843}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 506
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239853}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 507
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239863}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 508
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239873}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 509
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239883}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 510
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239893}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 511
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239903}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 512
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239913}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 513
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239923}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 514
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239933}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 515
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239943}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 516
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239953}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 517
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239963}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 518
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239973}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 519
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239983}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 520
# {'sensor': 'S1', 'smoke': True, 'ts': 1606239993}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 521
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240003}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 522
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240013}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 523
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240023}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 524
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240033}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 525
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240043}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 526
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240053}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 527
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240063}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 528
# ...
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240473}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 569
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240483}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 570
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240493}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 571
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240503}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 572
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240513}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 573
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240523}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 574
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240533}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 575
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240543}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 576
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240553}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 577
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240563}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 578
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240573}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 579
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240583}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 580
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240593}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 581
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240603}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 582
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240613}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 583
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240623}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 584
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240633}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 585
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240643}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 586
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240653}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 587
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240663}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 588
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240673}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 589
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240683}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 590
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240693}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 591
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240703}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 592
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240713}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 593
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240723}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 594
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240733}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 595
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240743}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 596
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240753}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 597
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240763}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 598
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240773}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 599
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240783}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 600
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240793}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 601
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240803}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 602
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240814}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 603
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240824}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 604
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240834}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 605
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240844}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 606
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240854}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 607
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240864}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 608
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240874}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 609
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240884}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 610
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240894}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 611
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240904}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 612
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240914}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 613
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240924}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 614
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240934}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 615
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240944}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 616
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240954}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 617
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240964}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 618
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240974}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 619
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240984}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 620
# {'sensor': 'S1', 'smoke': True, 'ts': 1606240994}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 621
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241004}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 622
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241014}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 623
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241024}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 624
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241034}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 625
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241044}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 626
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241054}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 627
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241064}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 628
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241074}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 629
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241084}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 630
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241094}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 631
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241104}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 632
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241114}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 633
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241124}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 634
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241134}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 635
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241144}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 636
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241154}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 637
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241164}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 638
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241174}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 639
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241184}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 640
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241194}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 641
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241204}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 642
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241214}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 643
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241224}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 644
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241234}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 645
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241244}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 646
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241254}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 647
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241264}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 648
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241274}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 649
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241284}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 650
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241294}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 651
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241304}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 652
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241314}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 653
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241324}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 654
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241334}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 655
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241344}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 656
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241354}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 657
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241364}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 658
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241374}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 659
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241384}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 660
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241394}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 661
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241404}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 662
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241414}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 663
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241424}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 664
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241434}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 665
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241444}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 666
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241454}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 667
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241464}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 668
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241474}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 669
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241484}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 670
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241494}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 671
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241504}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 672
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241514}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 673
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241524}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 674
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241534}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 675
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241544}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 676
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241554}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 677
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241564}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 678
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241574}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 679
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241584}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 680
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241594}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 681
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241604}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 682
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241614}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 683
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241624}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 684
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241634}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 685
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241644}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 686
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241654}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 687
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241664}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 688
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241674}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 689
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241684}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 690
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241694}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 691
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241704}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 692
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241714}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 693
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241724}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 694
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241734}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 695
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241744}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 696
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241754}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 697
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241764}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 698
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241774}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 699
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241784}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 700
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241794}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 701
# {'sensor': 'S1', 'smoke': True, 'ts': 1606241804}
# Produced record to topic SmokeSensorEvent partition [0] @ offset 702
